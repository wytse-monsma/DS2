# %% [markdown]
# ## Import libs

# %%
from BaseXClient import BaseXClient as basex

# Connect to BaseX Server
session = basex.Session('localhost', 1984, 'admin', '123')

def run_xpath(query, path = "Downloads/voc.xml"):
    xquery = f"""
    for $b in doc("{path}")/VOC {query}
    return $b
    """
    return run_xquery(xquery)

def run_xquery(xquery):
    return session.query(xquery).execute().split("\n")

# %% [markdown]
# ## Path queries
# (a) Return all all boatname elements of all voyages in the document.

# %%
run_xpath("/voyage/leftpage/boatname/text()")
# Out:
# ['BRESLAU',
#  'LES DEUX SOEURS',
#  'POTSDAM',
#  'GERECHTIGHEID',
#  'MAGDEBURG',
#  'WILLEM DE VIJFDE',
#  'PRINZ HEINRICH',
#  'ROTTERDAMS WELVAREN',
#  'FACTOR',
#  'OUWERKERK',
#  "L'HARMONIE",
#  'ZEEPAARD',
#  'ZEEUW',
#  "L'ANGELIQUE BENECH",
#  'LOUIS FRANCOIS',
#  'FRIEDRICH DER GROSSE',
#  'KROONPRINS VAN PRUISEN',
#  'DOLFIJN',
#  'OOSTEREEM',
#  'AURICH',
#  'HUIS TE KROOSWIJK',
#  'HOOP',
#  'TROMPENBURG',
#  'SLOT TER HOGE',
#  'HOF TER LINDEN',
#  'HERSTELDER',
#  'MERENBERG',
#  'DIAMANT',
#  'KATWIJK AAN DEN RIJN',
#  'MERCLUR',
#  'VRIENDSCHAP',
#  'HELD WOLTEMADE',
#  'GOUVERNEUR-GENERAAL DE CLERCK',
#  'TRITON',
#  'HARNIONIE',
#  'BERKHOUT',
#  'DAPPERHEID',
#  'DOGGERSBANK',
#  'JONGE FRANK',
#  "'T LOO",
#  'MEERMIN',
#  'ZWALUW',
#  'LES QUATRES FRERES',
#  'VREDE EN VRIJHEID',
#  'VREDE',
#  'ONZEKERE',
#  'HOOLWERF',
#  'HINDELOOPEN',
#  "L'ESPERANCE DE LA PRIX",
#  'VROUWE EVERHARDINA',
#  'PRINSES VAN ORANJE',
#  'BREDERODE',
#  'ROZENBURG',
#  'DRAAK',
#  'STRALEN',
#  'ZEEDUIN',
#  'BLEIJENBURG',
#  'STAVENISSE',
#  'VROUWE WIJNANDA LUBERTA',
#  'VRIJHEID',
#  'BATAVIER',
#  'SCHELDE',
#  'VREDE',
#  'EENSGEZINDHEID',
#  'EIK EN LINDE',
#  'EIKENWOUD',
#  'SPAARNE',
#  'EENPARIGHEID',
#  'MENTOR',
#  'LAM',
#  'CONSTANTIA',
#  'DORDRECHT',
#  'VROUWE JOHANNA JAKOBA',
#  'VLUGGE TREKVOGEL',
#  'WILLEM EN JAN',
#  'JONGE JAKOB',
#  'RESOLUTIE',
#  'CASTOR',
#  'VOORSCHOTEN',
#  'MIDDELWIJK',
#  'HOOP',
#  'OUDENAARDE',
#  'BARBESTEIN',
#  'HUISDUINEN',
#  'JAVA',
#  'PAREL',
#  'SPARENRIJK',
#  'ZEEPAARD',
#  'NEERLANDS VRIJHEID',
#  'MEEUWTJE',
#  'AFRIKAAN',
#  'AVENHORN',
#  'SLOT TER HOGE',
#  "NOSTRA SENHORA DE L'AMPRADOZA",
#  'GERECHTIGHEID',
#  'ALBLAS.SERDAM',
#  'JAN EN KORNELIS',
#  'IJSTROOM',
#  'FACTOR',
#  'GEERTRUIDA',
#  'JOSEPHUS DE TWEEDE',
#  'ROTTERDAMS WELVAREN',
#  'BEVERWIJK',
#  'VROUWE JAKOBA MARIA LUCIA THERESIA',
#  'RIDDERKERK',
#  'SCHOONDERLOO',
#  'OUD HAARLEM',
#  'VROUWE KATHARINA JOHANNA',
#  'NEGOTIE',
#  'TEXELSTROOM',
#  'ZAANSTROOM',
#  'ZEENIMF',
#  'ZOUTMAN',
#  'TWEE GEZUSTERS',
#  'HUIS OM',
#  'WOESTDUIN',
#  'PATRIOT',
#  'JONGE SAMUEL',
#  'ABBEKERK',
#  'RIDDERKERK',
#  'HOF TER LINDEN',
#  'RITTHEM',
#  'JONGE LIEVE',
#  'NIEUW RHOON',
#  'EUROPA',
#  'MORGENSTER',
#  'LAM',
#  'HONKOOP',
#  'WILLEM DE VIJFDE',
#  'VELDHOEN',
#  'ZUID-BEVELAND',
#  'HOOP',
#  'MERCUUR',
#  'KATWIJK AAN DEN RIJN',
#  'BOT',
#  'JONGE HUGO',
#  'INDIAAN',
#  'BARTHA PETRONELLA',
#  "'T LOO",
#  'DANKBAARHEID',
#  'GROENENDAAL',
#  'MARS',
#  'COMPAGNIES WELVAREN',
#  'BOTLAND',
#  'ALKEMADE',
#  'HOOGKARSPEL',
#  'BEEMSTER WELVAREN',
#  'CERES',
#  'OOSTKAPELLE',
#  'VRIJHEID',
#  'BOVENKERKER POLDER',
#  'HOOLWERF',
#  'ZILVEREN LEEUW',
#  'HOOP',
#  'OUD HAARLEM',
#  'LANDSKROON',
#  'TEMPEL',
#  'NOORDBEEK',
#  'PALLAS',
#  'WESTERVELD',
#  'VROUWE ANTHOINETTA KOENRARDINA',
#  'BORSSELE',
#  'BREDENHOF',
#  'FOREEST',
#  "'T LOO",
#  'HUIS TER MEYEN',
#  'HUIS TE BIJWEG',
#  'OVERHOUT',
#  'ASCHAT',
#  'POPKENSBURG',
#  'JONGE HELLINGMAN',
#  'HOLLAND',
#  'EUROPA',
#  'VOORBERG',
#  'BEEKVLIET',
#  'WESTFRIESLAND',
#  'WOESTDUIN',
#  'OUWERKERK',
#  'RIDDERKERK',
#  'VROUWE MARGARETHA MARIA',
#  'BARTHA PETRONELLA',
#  'JONGE LIEVE',
#  'JUNO',
#  'VROUWE KORNELIA HILLEGONDA',
#  'HUIS TE KROOSWIJK',
#  'VREEBURG',
#  'AZIE',
#  'BOTLAND',
#  'VROUWE MARIA JAKOBA',
#  'NOORD-BEVELAND',
#  'ZUID-BEVELAND',
#  'BOT',
#  'HERSTELDER',
#  'NIEUW RHOON',
#  'JONGE SAMUEL',
#  'PRINSES VAN ORANJE',
#  'VELDHOEN',
#  'BOVENKERKER POLDER',
#  'DUINENBURG',
#  'MERCUUR',
#  'OOSTKAPELLE',
#  'USSELMONDE',
#  'BORSSELE',
#  'WELGELEGEN',
#  'BLEIJENBURG',
#  'ZON',
#  'ALKEMADE',
#  'RITTHEM',
#  'GROENENDAAL',
#  'PAUW',
#  'HONKOOP',
#  'WILLEM DE VIJFDE',
#  'HUTS TE BIJWEG',
#  'VROUWE ELISABETH',
#  'VROUWE GEERTRUIDA',
#  'LANDSKROON',
#  'HUIS OM',
#  'OUWERKERK',
#  'JONGE THOMAS',
#  'VREEBURG',
#  'LANDS WELVAREN',
#  'LAM',
#  "'T LOO",
#  'OUD HAARLEM',
#  'BLEISWIJK',
#  'RITTHEM',
#  'RENSWOUDE',
#  'WESTERVELD',
#  'DUIVENBRUG',
#  'ZON',
#  'RIJNSBURG',
#  'BARTHA PETRONELLA',
#  'PALLAS',
#  'HOOLWERF',
#  'ASCHAT',
#  'AZIE',
#  'RIDDERKERK',
#  'VLISSINGEN',
#  'WOESTDUIN',
#  'GEINWENS',
#  'BOVENKERKER POLDER',
#  'BOT',
#  'JONGE HELLINGMAN',
#  'PRINSES VAN ORANJE',
#  'WILLEM DE VIJFDE',
#  'ZILVEREN LEEUW',
#  'SCHOONZICHT',
#  'DAMZICHT',
#  "'S LANDS WELVAREN",
#  'VELSEN',
#  'ZUID-BEVELAND',
#  'WESTFRIESLAND',
#  'VROUWE KORNELIA HILLEGONDA',
#  'KRONENBURG',
#  'NIEUW RHOON',
#  'VROUWE ANTHOINETTA KOENRARDINA',
#  'JONGE LIEVE',
#  'HUIS TER MEYEN',
#  'JONGE SAMUEL',
#  'DUINENBURG',
#  'BARBARA THEODORA',
#  'SCHAGEN',
#  'VREDESTEIN',
#  'VROUWE GEERTRUIDA',
#  'OUD HAARLEM',
#  "'T LOO",
#  'OOSTKAPELLE',
#  'TEMPEL',
#  'VROUWE MARGARETHA MARIA',
#  'VROUWE MARIA JAKOBA',
#  'VROUWE PETRONELLA MARIA',
#  'VREDELUST',
#  'ENKHUIZEN',
#  'VAILLANT',
#  'BLEIJENBURG',
#  'IJSSELMONDE',
#  'DAMZICHT',
#  'LEIMUIDEN',
#  'RIJNSBURG',
#  'VREEBURG',
#  'ASCHAT',
#  'HUIS OM',
#  'POPKENSBURG',
#  'COMPAGNIES WELVAREN',
#  'PALLAS',
#  'HUTS TE BIJWEG',
#  'VELDHOEN',
#  'WALENBURG',
#  'KRONENBURG',
#  'NIEUW RHOON',
#  'SCHOLTENBURG',
#  'VLISSINGEN',
#  'JONGE THOMAS',
#  'WOESTDUIN',
#  'PAUW',
#  'WILLEM DE VIJFDE',
#  'ZILVEREN LEEUW',
#  'NIJENBORG',
#  'RENSWOUDE',
#  'BLEISWIJK',
#  'JERUSALEM',
#  'BARTHA PETRONELLA',
#  'BLIJDORP',
#  'BORSSELE',
#  'BOVENKERKER POLDER',
#  'DUIVENBRUG',
#  'ERFPRINS',
#  'LANDSKROON',
#  'RIDDERKERK',
#  'JONGE SAMUEL',
#  'VROUWE GEERTRUIDA',
#  'RUITEVELD',
#  'GANZENHOEF',
#  'PALLAS',
#  'GEINWENS',
#  'VROUWE MARGARETHA MARIA',
#  'VROUWE ANTHOINETTA KOENRARDINA',
#  'AZIE',
#  'VROUWE ELISABETH',
#  'BURCH',
#  'NOORD-BEVELAND',
#  'VROUWE PETRONELLA MARIA',
#  'SCHOONZICHT',
#  'WESTFRIESLAND',
#  'HUIS TE BIJWEG',
#  'DUINENBURG',
#  'LEKKERLUST',
#  'LYCOCHTON',
#  'RTTTHEM',
#  'WELGELEGEN',
#  'COMPAGNIES WELVAREN',
#  'OUDERAMSTEL',
#  'VROUWE KORNELIA HILLEGONDA',
#  'NIEUW RHOON',
#  'JONGE THOMAS',
#  'BARTHA PETRONELLA',
#  'JONGE LIEVE',
#  "'S LANDS WELVAREN",
#  'JONKVROUWE KORNELIA JAKOBA',
#  'VREDESTEIN',
#  'GOUVERNEUR-GENERAAL',
#  'SNOEK',
#  'VLIETLUST',
#  'WESTERVELD',
#  'VROUWE ELISABETH DOROTHEA',
#  'ENKHUIZEN',
#  'KRONENBURG',
#  'ZILVEREN LEEUW',
#  'NOORD NIEUWLAND',
#  'VELSEN',
#  'VREEBURG',
#  'WALCHEREN',
#  'HUIS OM',
#  'ORANJEZAAL',
#  'RENSWOUDE',
#  'JONGE SAMUEL',
#  'OVERNES',
#  'BARBARA THEODORA',
#  'BLUDORP',
#  'SCHOONZICHT',
#  'NOORD-BEVELAND',
#  'VREDENHOF',
#  'PALLAS',
#  'WALENBURG',
#  'BLEISWIJK',
#  'SCHAGEN',
#  'DAMZICHT',
#  'LEIMUIDEN',
#  'NIJENBORG',
#  'BAARZANDE',
#  'VROUWE ELIZABETH',
#  "'S GRAVENZANDE",
#  'KEUKENHOF',
#  'LAPIENENBURG',
#  'ADMIRAAL DE RUYTER',
#  'TULPENBURG',
#  'ZUID-BEVELAND',
#  'KATTENDUKE',
#  'SCHOLTENBURG',
#  'KIEVITSHEUVEL',
#  'ASCHAT',
#  'HUIS OM',
#  'RUITEVELD',
#  "'S LANDS WELVAREN",
#  'VROUWE CORNELIA HILLEGONDA',
#  'STRALEN',
#  'VOSMAAR',
#  'JERUSALEM',
#  'EENDRACHT',
#  'LUXEMBURG',
#  'WESTFRIESLAND',
#  'LYCOCHTON',
#  'VROUWE PETRONELLA',
#  'BORSSELE',
#  'HUIS TEN DONK',
#  'DUINENBURG',
#  'GOUVERNEUR-GENERAAL',
#  'JONGE LIEVE',
#  'SNOEK',
#  'ERFPRINS',
#  'VREDESTEIN',
#  'LEKKERLUST',
#  'HUIS TE BOEDE',
#  'ORANJEZAAL',
#  'BLIJDORP',
#  'OOSTHUIZEN',
#  'WELGELEGEN',
#  'OVERNES',
#  'HUIS TE BIJWEG',
#  'SLOTEN',
#  'WESTERVELD',
#  'VLISSINGEN',
#  'RADERMACHER',
#  'SLOTERKIJK',
#  'DE DRIE PAPEGAAIEN',
#  'VRIJBURG',
#  'VROUWE ELIZABETH DOROTHEA',
#  'NIEUW NIEUWERKERK',
#  'VELSEN',
#  'VOORLAND',
#  'NOORD-BEVELAND',
#  'BRONSTEE',
#  'BAARZANDE',
#  'BLEISWIJK',
#  'VROUWE GEERTRUIDA',
#  'NOORD NIEUWLAND',
#  'OUDERAMSTEL',
#  'BURCH',
#  'HOOP',
#  'LIEFDE',
#  'LYCOCHTON',
#  'OUDKARSPEL',
#  'VOSMAAR',
#  'WALCHEREN',
#  'AMERONGEN',
#  'ASCHAT',
#  'VROUWE PETRONELLA MARIA',
#  'ADMIRAAL DE RUYTER',
#  'SCHOLTENBURG',
#  'VISVLIET',
#  'DAMZICHT',
#  'JONGE LIEVE',
#  "'S GRAVENZANDE",
#  'KATTENDIJKE',
#  'WILDRIJK',
#  'BOSSCHENHOVE',
#  'LUXEMBURG',
#  'RUITEVELD',
#  'VLIETLUST',
#  'DUINENBURG',
#  'SCHOONZICHT',
#  'IMMAGONDA',
#  'VROUWE ELIZABETH',
#  'HUIS TEN DONK',
#  'ERFPRINS',
#  'GOUVERNEUR-GENERAAL',
#  'KIEVITSHEUVEL',
#  'LAPIENENBURG',
#  'LEKKERLAND',
#  'NIJENBORG',
#  'SCHAGEN',
#  'SNOEK',
#  'STRALEN',
#  'TORENVLIET',
#  'ZUID-BEVELAND',
#  'KEUKENHOF',
#  'BARBARA THEODORA',
#  'OVERSCHIE',
#  'VROUWE PETRONELLA',
#  'RADERMACHER',
#  'SLOTEN',
#  'LEKKERLUST',
#  'GIESSENBURG',
#  'WALCHEREN',
#  'AMELISWEERT',
#  'HUIS TE BOEDE',
#  'IMMAGONDA',
#  'LIEFDE',
#  'VRIJBURG',
#  'VROUWE GEERTRUIDA',
#  'KRONENBURG',
#  'VROUWE PETRONELLA MARIA',
#  'WELGELEGEN',
#  'SCHOLTENBURG',
#  'BLIJDORP',
#  'NOORD NIEUWLAND',
#  'NOORD-BEVELAND',
#  'OUDKARSPEL',
#  'RHOON',
#  'ADMIRAAL DE RUYTER',
#  'SCHAGEN',
#  'AMSTELVEEN',
#  'BAARZANDE',
#  'HOOP',
#  'VROUWE REBECCA JACOBA',
#  'TULPENBURG',
#  'HUIS TEN DONK',
#  'VISVLIET',
#  'TORENVLIET',
#  'RENSWOUDE',
#  'GUSTAAF WILLEM',
#  'VOORLAND',
#  'BUITENZORG',
#  'STANDVASTIGHEID',
#  'AMERONGEN',
#  'VROUWE ELIZABETH',
#  'LANGEWIJK',
#  'LYCOCHTON',
#  'NIEUW NIEUWERKERK',
#  'STRALEN',
#  'VOSMAAR',
#  'ROTTERDAM',
#  'SNOEK',
#  'VROUWE PETRONELLA',
#  'WILDRIJK',
#  'LAPIENENBURG',
#  'OVERNES',
#  'VELSEN',
#  'JERUSALEM',
#  'VLIETLUST',
#  'LUXEMBURG',
#  'LEKKERLAND',
#  'ZUIDERBURG',
#  'HUIS TE MANPAD',
#  'PIJLSWAART',
#  'BARBARA THEODORA',
#  'BEVALLIGHEID',
#  'BOSSCHENHOVE',
#  'GETROUWIGHEID',
#  'GOUVERNEUR-GENERAAL',
#  'KIEVITSHEUVEL',
#  'OVERSCHIE',
#  'SLOTERDIJK',
#  'OUDKARSPEL',
#  'WILDRUK',
#  'GIESSENBURG',
#  'WAAKZAAMHEID',
#  'BEVALLIGHEID',
#  'EENDRACHT',
#  'ELSWOUD',
#  'LANGEWIJK',
#  'OOSTHUIZEN',
#  'STANDVASTIGHEID',
#  'VOSMAAR',
#  'ERFPRINS',
#  'HERSTELDER',
#  'LEIDEN',
#  'NOORD NIEUWLAND',
#  'PASGELD',
#  'PRINSES CAROLINA',
#  'HERCULES',
#  'HUIGENWAARD',
#  'SLOTEN',
#  'NAARSTIGHEID',
#  'JAGER',
#  'NIEUWVIJVERVREUGD',
#  'LUXEMBURG',
#  'NIEUW NIEUWERKERK',
#  'ZUIDERBURG',
#  'DIEMEN',
#  'AMSTELVEEN',
#  'GELDERMALSEN',
#  'VOORZICHTIGHEID',
#  'HAARLEM',
#  'BLOEMENDAAL',
#  'ZAAMSLAG',
#  'MEERVLIET',
#  'ROTTERDAM',
#  'SPANDERSWOUD',
#  'BAARZANDE',
#  'GERECHTIGHEID',
#  'WOITKENSDORP',
#  'OQSTKAPELLE',
#  'STRALEN',
#  'HECTOR',
#  'WITSBURG',
#  'BATAVIER',
#  'GETROUWIGHEID',
#  'BREDENHOF',
#  'VREDE',
#  'KASTEEL VAN TILBURG',
#  'HUIS TE MANPAD',
#  'KIEVITSHEUVEL',
#  'SLOTERDIJK',
#  'HERSTELDER',
#  'HUIS TER DUINE',
#  'OVERNES',
#  'NIEUWVIJVERVREUGD',
#  'WAPEN VAN HOORN',
#  'KRABBENDIJKE',
#  'OVERSCHIE',
#  'BROUWER',
#  'GOUVERNEUR-GENERAAL',
#  'ADMIRAAL DE RUYTER',
#  'WAAKZAAMHEID',
#  'HUIS TEN DONK',
#  'HUIGENWAARD',
#  'OUWERKERK',
#  'HUIS TE RENSBURG',
#  'HOOP',
#  'BEVALLIGHEID',
#  'VOSMAAR',
#  'IMMAGONDA',
#  'LIEFDE',
#  'AKERENDAM',
#  'JAGER',
#  'GUSTAAF WILLEM',
#  'ARNESTUN',
#  'NIEUWSTAD',
#  'BAARZANDE',
#  'SCHAKENBOS',
#  'NOT USED',
#  'DIEMEN',
#  'HERCULES',
#  'SPANDERSWOUD',
#  'SLOTEN',
#  'EENDRACHT',
#  "HOF D'UNO",
#  'KLEVERSKERKE',
#  'LANGEWIJK',
#  'OOSTKAPELLE',
#  'SLOT VAN KAPELLE',
#  'LEKKERLAND',
#  'BREDENHOF',
#  'STANDVASTIGHEID',
#  'PRINSES VAN ORANJE',
#  'SPARENRIJK',
#  'ELSWOUD',
#  'HARTEKAMP',
#  'PASGELD',
#  'TOLSDUIN',
#  'BEVALLIGHEID',
#  'SLOTERDIJK',
#  'VOSMAAR',
#  'OSDORP',
#  'LEIDEN',
#  'AMSTELVEEN',
#  'FORTUIN',
#  'IMMAGONDA',
#  'NAARSTIGHEID',
#  'ZAAMSLAG',
#  'BROUWER',
#  'HUTS TE RENSBURG',
#  'SPARENRIJK',
#  'WOITKENSDORP',
#  'GERECHTIGHEID',
#  'HUTS TE MANPAD',
#  'SPANDERSWOUD',
#  'ZUIDERBURG',
#  'HUTS TER DUINE',
#  'OVERNES',
#  'WILDRIJK',
#  'BATAVIER',
#  'ANNA',
#  'KASTEEL VAN TILBURG',
#  'HOOP',
#  'OVERSCHIE',
#  'VOORZICHTIGHEID',
#  'DOMBURG',
#  'VRIJHEID',
#  'WELTEVREDEN',
#  'ROOSWIJK',
#  'BAARZANDE',
#  'AKERENDAM',
#  'GUSTAAF WILLEM',
#  'PASGELD',
#  'KRABBENDUKE',
#  'SCHEIJBEEK',
#  'WESTHOVEN',
#  'LEKKERLAND',
#  "HOF D'UNO",
#  'LIS',
#  'HERCULES',
#  'ARNESTIJN',
#  'POLANEN',
#  'BOSBEEK',
#  'DIEMEN',
#  'DUINHOF',
#  'HAARLEM',
#  'SLOT VAN KAPELLE',
#  'TOLSDUIN',
#  'EENDRACHT',
#  'ZEELANDIA',
#  'DISHOEK',
#  'GETROUWIGHEID',
#  'HUIS TE RENSBURG',
#  'STANDVASTIGHEID',
#  'DIEMERMEER',
#  'DUINENBURG',
#  'NIEUWLAND',
#  'DIEMEN',
#  'HUIS TER DUINE',
#  'DOMBURG',
#  'SCHELLAG',
#  'WELTEVREDEN',
#  'KLEVERSKERKE',
#  'FORTUIN',
#  'EINDHOEF',
#  'HUIGENWAARD',
#  'RUST EN WERK',
#  'HOGERSMILDE',
#  'LEIDEN',
#  'REIGERSDAAL',
#  'SPANDERSWOUD',
#  'BROUWER',
#  'DUINHOF',
#  'HUIS TE PERSIJN',
#  'VOORZICHTIGHEID',
#  'ZAAMSLAG',
#  'ZUIDERBURG',
#  'KERKWUK',
#  'KNAPPENHOF',
#  'NIEUW WALCHEREN',
#  'BATAVIER',
#  'HOOP',
#  'STANDVASTIGHEID',
#  'VLISSINGEN',
#  'BOSBEEK',
#  'OVERNES',
#  'HEUVEL',
#  'OPLETTENDHEID',
#  'TOEVALLIGHEID',
#  'POPKENSBURG',
#  'TOLSDUIN',
#  'RUST EN WERK',
#  'SIJBEKARSPEL',
#  'WOITKENSDORP',
#  'GERECHTIGHEID',
#  'AKERENDAM',
#  'OUWERKERK',
#  'BEUKESTIJN',
#  'SARA JACOBA',
#  'SCHEUBEEK',
#  'GUNTERSTUN',
#  'WELTEVREDEN',
#  'PATMOS',
#  'FORTUIN',
#  'LIS',
#  'STRIJEN',
#  'DISHOEK',
#  'KRABBENDIJKE',
#  'MAARSSEVEEN',
#  'SCHELLAG',
#  'ZAAMSLAG',
#  'HUIS TE RENSBURG',
#  'ARNESTUN',
#  'HUIS TER DUINE',
#  'HARTENLUST',
#  'WESTKAPELLE',
#  'NIEUWSTAD',
#  'WESTHOVEN',
#  'POLANEN',
#  'GOIDSCHALXOORD',
#  'LEEUWERIK',
#  'ANNA',
#  'DOMBURG',
#  'DRECHTERLAND',
#  'DUINENBURG',
#  'EENDRACHT',
#  'HERSTELDER',
#  'HOFVLIET',
#  'IDA',
#  'NIEUWERKERK',
#  'SCHONAUWEN',
#  'VELSEN',
#  'VRIJHEID',
#  'KRABBENDUKE',
#  'MEERLUST',
#  'REIGERSDAAL',
#  'SIJBEKARSPEL',
#  'WOITENSDORP',
#  'KNAPPENHOF',
#  'MARIA ADRIANA',
#  'RIJNHUIZEN',
#  'VREELAND',
#  'HECTOR',
#  'HOF VAN DELFT',
#  'RUST EN WERK',
#  'JONGE WILLEM',
#  'DIEMERMEER',
#  'KETEL',
#  'HUIS TE MARQUETTE',
#  'OUWERKERK',
#  'HUIS TE FOREEST',
#  'NIEUWLAND',
#  'TOLSDUIN',
#  'BOSBEEK',
#  'HAAMSTEDE',
#  'RUITER',
#  'DUDE ZIJPE',
#  'STRUEN',
#  'ENKHUIZEN',
#  'ABBEKERK',
#  'MAARSSEVEEN',
#  'RUYVEN',
#  'HORSTENDAAL',
#  'HOGERSMILDE',
#  'WELTEVREDEN',
#  'WESTERBEEK',
#  'KASTEEL VAN WOERDEN',
#  'HEUVEL',
#  'ROZENBEEK',
#  'SCHELLAG',
#  'WATERVLIET',
#  'PAPENBURG',
#  'WICKENBURG',
#  'ARNESTUN',
#  'POLANEN',
#  'AMSTERDAM',
#  'BATAVIER',
#  'HOFVLIET',
#  'HUIS TE SPIJK',
#  'ANANAS',
#  'HUIS TER DUINE',
#  'HORSSEN',
#  'KNAPPENHOF',
#  'SIJBEKARSPEL',
#  'HILVERSBEEK',
#  'NIEUW WALCHEREN',
#  'BETHLEHEM',
#  'LOVERENDAAL',
#  'HUIS TE MARQUETTE',
#  'SCHEIJBEEK',
#  'ADRICHEM',
#  'HOF VAN DELFT',
#  'NIEUWERKERK',
#  'LANGEWIJK',
#  'BEUKESTIJN',
#  'EVERSWAART',
#  'GOIDSCHALXOORD',
#  'HOFWEGEN',
#  'OUWERKERK',
#  'RIJNHUIZEN',
#  'SARA JACOBA',
#  'VREELAND',
#  'DISHOEK',
#  'VENENBURG',
#  'HUIS DEN EULT',
#  'KERKWIJK',
#  'DIEMERMEER',
#  'NIEUWVLIET',
#  'HUIS TE RENSBURG',
#  'VOORDUIN',
#  "'S HEER ARENDSKERKE",
#  'DELFLAND',
#  'DUIFJE',
#  'PATMOS',
#  'POPKENSBURG',
#  'HARTENLUST',
#  'NOORDWOLFSBERGEN',
#  'RUST EN WERK',
#  'WESTHOVEN',
#  'COXHOORN',
#  'HAAMSTEDE',
#  'RUITER',
#  'VLISSINGEN',
#  'KERKZICHT',
#  'KLARABEEK',
#  'SINT LAURENS',
#  'KASTEEL VAN TILBURG',
#  'PALLAS',
#  'DRECHTERLAND',
#  'ENKHUIZEN',
#  'WAPEN VAN HOORN',
#  'SCHELLAG',
#  'KASTEEL VAN WOERDEN',
#  'RUYVEN',
#  'JONGE WILLEM',
#  'GUNTERSTUN',
#  'LEIDUIN',
#  'MEERLUST',
#  'ZWAAN',
#  'ALBLASSERDAM',
#  'ZUIDPOOL',
#  'MEERMIN',
#  'JONGE BONIFACIUS',
#  'LOUISA ANTHONY',
#  'VERTROUWEN',
#  'HOUGLY',
#  'KROMHOUT',
#  'MENTOR',
#  'SURSEANCE',
#  'CEYLON',
#  'MAKASSAR',
#  'NOORD-HOLLAND',
#  'STANDVASTIGHEID',
#  'VLIJT',
#  'SIAM',
#  'WASHINGTON',
#  'ZEELELIE',
#  'CASTOR',
#  'DUIFJE',
#  'GOUDA',
#  'DEMERARY',
#  'GERECHTIGHEID',
#  'FAAM',
#  'RESOLUTIE',
#  'MARIA LOUISA',
#  'TEXELSTROOM',
#  'KRAAI',
#  'EXPEDITIE',
#  'AFRIKAAN',
#  'WESTKAPELLE',
#  'BUITENVERWACHTING',
#  'VROUWE MARIA KORNELIA',
#  'OOSTHUIZEN',
#  'ZEELAND',
#  'LEIDEN',
#  'ROZENBURG',
#  'JONKVROUWE SIBILLA ANTHOINETTA',
#  'VERWACHTING',
#  'VOORLAND',
#  'DRECHTERLAND',
#  'DRIE GEBROEDERS',
#  'BARBESTEIN',
#  'STAR',
#  'VROUWE KATHARINA JOHANNA',
#  'MAKASSAR',
#  'CONSTITUTIE',
#  'GEERTRUIDA EN PETRONELLA',
#  'NIEUWSTAD',
#  'GOUVERNEUR-GENERAAL MOSSEL',
#  'RUSTHOF',
#  'UNIE',
#  'STANDVASTIGHEID',
#  'VREDENBURG',
#  'ALBLASSERDAM',
#  'BLITTERSWIJK',
#  'VROUWE AGATHA',
#  'HAASJE',
#  'STRALEN',
#  'CHRISTOFFEL COLUMBUS',
#  'SNELHEID',
#  'GOUVERNEUR FALCK',
#  'SCHOONDERLOO',
#  'LUCHTBOL',
#  'OOSTZAANDAM',
#  'ZEEMEEUW',
#  'TEXELSTROOM',
#  'EENPARIGHEID',
#  'ZWAAN',
#  'DORDRECHT',
#  'DRAAK',
#  'KRAAI',
#  'MENTOR',
#  'HOORNWEG',
#  'HORSSEN',
#  'VASCO DA GAMA',
#  'AFRIKAAN',
#  'EENSGEZINDHEID',
#  'MARIA LOUISA',
#  'BROEDERSLUST',
#  'BEVERWIJK',
#  'BERKHOUT',
#  'LEVIATHAN',
#  'VLIJT',
#  'HELENA LOUISA',
#  'DUIFJE',
#  'SURSEANCE',
#  'PHOENICWR',
#  'SNELHEID',
#  'NOORD-HOLLAND',
#  'JONGE JAKOB',
#  'GOUDA',
#  'CONSTANTIA',
#  'RECHT DOOR ZEE',
#  'SCHELDE',
#  'GOUVERNEUR-GENERAAL DE CLERCK',
#  'UNIE',
#  'SINT LAURENS',
#  'EXPEDITIE',
#  'FAAM',
#  'TEILINGEN',
#  'VROUWE MARIA KORNELIA',
#  'SCHAGEN',
#  'DORDWIJK',
#  'HUISDUINEN',
#  'POLLUX',
#  'VERWACHTING',
#  'TRINCONOMALE',
#  'SLOT CAPELLE',
#  'MEEUWTJE',
#  'ZEENIMF',
#  'SLOT TER HOGE',
#  'HAASJE',
#  'NEGOTIE',
#  'VEERE',
#  'AREND',
#  'ZAANSTROOM',
#  'RESOLUTIE',
#  'ROTTERDAMS WELVAREN',
#  'ZEELAND',
#  'EIK EN LINDE',
#  'LUCHTBOL',
#  'CHRISTOFFEL COLUMBUS',
#  'DELFT',
#  'MEERWIJK',
#  'VROUWE SARA HENDRINA',
#  'DAPPERHEID',
#  'BERKSHOVEN',
#  ...]

# %% [markdown]
# (b) Some voyage elements contain an element hired which indicates that the boat was hired for that voyage. Return the boatname elements that have been hired.

# %%
run_xpath("/voyage/leftpage[./hired]/boatname/text()")
# Out:
# ['BRESLAU',
#  'POTSDAM',
#  'MAGDEBURG',
#  'PRINZ HEINRICH',
#  'FACTOR',
#  "L'HARMONIE",
#  "L'ANGELIQUE BENECH",
#  'LOUIS FRANCOIS',
#  'FRIEDRICH DER GROSSE',
#  'KROONPRINS VAN PRUISEN',
#  'DOLFIJN',
#  'OOSTEREEM',
#  'AURICH',
#  'DAPPERHEID',
#  'JONGE FRANK',
#  'LES QUATRES FRERES',
#  'VREDE EN VRIJHEID',
#  'ONZEKERE',
#  "L'ESPERANCE DE LA PRIX",
#  'VROUWE WIJNANDA LUBERTA',
#  'VRIJHEID',
#  'VREDE',
#  'EENSGEZINDHEID',
#  'EIK EN LINDE',
#  'EIKENWOUD',
#  'MENTOR',
#  'DORDRECHT',
#  'VROUWE JOHANNA JAKOBA',
#  'VLUGGE TREKVOGEL',
#  'WILLEM EN JAN',
#  'JONGE JAKOB',
#  'OUDENAARDE',
#  'NEERLANDS VRIJHEID',
#  'JAN EN KORNELIS',
#  'FACTOR',
#  'GEERTRUIDA',
#  'JOSEPHUS DE TWEEDE',
#  'VROUWE JAKOBA MARIA LUCIA THERESIA',
#  'JONGE BONIFACIUS',
#  'LOUISA ANTHONY',
#  'VERTROUWEN',
#  'NOORD-HOLLAND',
#  'DRIE GEBROEDERS',
#  'GEERTRUIDA EN PETRONELLA',
#  'VROUWE AGATHA',
#  'OOSTZAANDAM',
#  'DORDRECHT',
#  'EENSGEZINDHEID',
#  'BROEDERSLUST',
#  'NOORD-HOLLAND',
#  'JONGE JAKOB',
#  'EIK EN LINDE',
#  'VROUWE SARA HENDRINA',
#  'DAPPERHEID',
#  'BERKSHOVEN',
#  'RIJNOORD',
#  'DRIETAL HANDELAARS',
#  'GATENISSE',
#  'GEERTRUIDA PETRONELLA',
#  'JAN EN KORNELIS',
#  'VROUWE JOHANNA JAKOBA',
#  'JONGE JAKOB EN ALBERTUS',
#  'VLUGGE TREKVOGEL',
#  'VROUWE JAKOBA MARIA LUCIA THERESIA',
#  'JOSEPHUS DE TWEEDE',
#  'GEERTRUIDA',
#  'WIRTZLUST',
#  'HANDELLUST',
#  'GOEDE HOOP',
#  'VROUWE SARA HENDRINA',
#  'VROUWE AGATHA',
#  'GOEDE VERWACHTING',
#  'MERENBERG',
#  'FORTUIN (VAN',
#  'DRIE GEBROEDERS',
#  'JUFFROUW JOHANNA',
#  'SUZANNA',
#  'ZEEVAART',
#  'EENSGEZINDHEID',
#  'MENTOR',
#  'OOSTZAANDAM',
#  'VLISSINGEN',
#  'MARIA',
#  'BROEDERSLUST',
#  'DORDRECHT',
#  'GOEDE INTENTIE',
#  'VREDE',
#  'JONGE FRANK',
#  'BERKSHOVEN',
#  'DAPPERHEID',
#  'VROUWE WIJNANDA LUBERTA',
#  'ONZEKERE',
#  'JONGE JAKOB',
#  'JUFFROUW JOHANNA',
#  'FACTOR',
#  'JAN EN KORNELIS',
#  'GEERTRUIDA',
#  'JOSEPHUS DE TWEEDE',
#  'OUDENAARDE',
#  'VROUWE JAKOBA MARIA LUCIA THERESIA',
#  'RUNOORD',
#  'EIK EN LINDE',
#  'MENTOR',
#  'ELISABETH ET SOPHIE',
#  'LE NEPTHUNE',
#  'WILLEM EN JAN',
#  'JONGE JAKOB',
#  'VROUWE JOHANNA JAKOBA',
#  'EIKENWOUD',
#  'VLUGGE TREKVOGEL',
#  'VROUWE WIJNANDA LUBERTA',
#  'LE CASTRIES',
#  'VREDE',
#  'VRIJHEID',
#  'LES QUATRES FRERES',
#  'LA RESOLUTION',
#  'EENSGEZINDHEID',
#  'DORDRECHT',
#  'LA CONJUNCTURE',
#  'JONGE FRANK',
#  'VREDE EN VRIJHEID',
#  'LES SIX FRERES',
#  'ONZEKERE',
#  "L'EMPEREUR ET ROI",
#  "L'ORION",
#  'LA COMPTESSE DU NORD',
#  'LE JEUNE STANISLAUS',
#  'DAPPERHEID',
#  'ROZENBURG',
#  'LE FABIUS',
#  'PRINZ HEINRICH',
#  "L'ESPERANCE DE LA PAIX",
#  'LA DAME JEANNE',
#  'LE CONCORDE',
#  "L'AIGLE NOIR",
#  'LA SAINTE THERESE',
#  'DOLFIJN',
#  'AURICH',
#  'POTSDAM',
#  'UHARMONIE',
#  'BRESLAU',
#  "L'ACTIVE",
#  "L'ANGELIQUE BENECH",
#  'KROONPRINS VAN PRUISEN',
#  'BERLIN',
#  'FRIEDRICH DER GROSSE',
#  'MAGDEBURG',
#  'FACTOR',
#  'VREDE EN VRIJHEID',
#  'ONZEKERE',
#  'JONGE FRANK',
#  'MARIA',
#  'DAPPERHEID W',
#  'VROUWE WUNANDA LUBERTA',
#  'BERKSHOVEN',
#  'OOSTZAANDAM',
#  'DORDRECHT',
#  'EENSGEZINDHEID',
#  'JONGE JAKOB',
#  'JUFFROUW JOHANNA',
#  'VREDE',
#  'MENTOR',
#  'VLISSINGEN',
#  'BROEDERSLUST',
#  'GOEDE INTENTIE',
#  'VLUGGE TREKVOGEL',
#  'MERENBERG',
#  'GOEDE VERWACHTING',
#  'EIK EN LINDE',
#  'GEERTRUIDA',
#  'SUSANNA',
#  'GOEDE HOOP',
#  'VROUWE JOHANNA JAKOBA',
#  'RIJNOORD',
#  'JAN EN KORNELIS',
#  'GEERTRUIDA PETRONELLA',
#  'VROUWE JAKOBA MARIA LUCIA THERESIA',
#  'WIRTZLUST',
#  'VROUWE AGATHA',
#  'GATENISSE',
#  'HANDELLUST',
#  'DAPPERHEID',
#  'BERKSHOVEN',
#  'JONGE JAKOB EN ALBERTUS',
#  'NOORD-HOLLAND',
#  'JONGE JAKOB',
#  'OOSTZAANDAM',
#  'DORDRECHT',
#  'VROUWE SARA HENDRINA',
#  'VROUWE AGATHA',
#  'AGATHA',
#  'SCHOLTENBURG',
#  'ALIDA',
#  'ENGEL MICHAEL',
#  'SNOEPER',
#  'ELISABETH',
#  'VLAMING',
#  'RAD VAN AVONTUUR',
#  'ROMEIN',
#  'JUFFROUW ANNA',
#  'JONAS',
#  'JUFFROUW MARIA',
#  'ROMEIN',
#  'JUFFROUW KORNELIA',
#  'SINT ANDRIES',
#  'BLOEMENDAAL',
#  'KRIJGSMAN',
#  'SNOEPER',
#  'GEKROONDE EENDRACHT',
#  'JUFFROUW MARIA',
#  'HOVELING',
#  'CONSTANTIA',
#  'VERGULDE TIJGER',
#  'CECILIA',
#  'OPPERDOES',
#  'ESPERANCE',
#  'GIDEON',
#  'JONGE PRINS TE PAARD',
#  'DRIE GEBROEDERS',
#  'GEERTRUIDA EN PETRONELLA',
#  'VROUWE AGATHA',
#  'DORDRECHT',
#  'GEERTRUIDA EN PETRONELLA',
#  'NOORD-HOLLAND',
#  'VROUWE MARIA GEERTRUIDA',
#  'BERLICUM',
#  'JONGE BONIFACIUS',
#  'EENSGEZINDHEID',
#  'LOUISA ANTHONY',
#  'VERTROUWEN',
#  'GEERTRUIDA',
#  'WESTERMEER',
#  'WILLEMSTAD EN BOETSELAAR',
#  'BUISJE',
#  'SNOEPER',
#  'AGATHA',
#  'ENGEL MICHAEL',
#  'ALIDA',
#  'SCHOLTENBURG',
#  'SNOEPER',
#  'ELISABETH',
#  'VLAMING',
#  'RAD VAN AVONTUUR',
#  'ROMEIN',
#  'JUFFROUW ANNA',
#  'JUFFROUW KORNELIA',
#  'ROMEIN',
#  'SNOEPER',
#  'JONAS',
#  'JUFFROUW MARIA',
#  'SINT ANDRIES',
#  'BLOEMENDAAL',
#  'KRIJGSMAN',
#  'SINT LAURENS',
#  'GEKROONDE EENDRACHT',
#  'JUFFROUW MARIA',
#  'HOVELING',
#  'NIEUWE VISSER',
#  'BLEKER',
#  'CATHARINA',
#  'SNOEPER',
#  'VERGULDE TIJGER',
#  'CECILIA',
#  'ESPERANCE',
#  'OPPERDOES',
#  'CONSTANTIA',
#  'DOFFER',
#  'EEKHOORN',
#  'GEKROONDE HARING',
#  'GIDEON',
#  'JONGE PRINS TE PAARD',
#  'EENSGEZINDHEID',
#  'BROEDERSLUST',
#  'VROUWE SARA HENDRINA',
#  'ZEEVAART',
#  'FORTUIN (VAN',
#  'DRIE GEBROEDERS',
#  'JOSEPHUS DE TWEEDE',
#  'DRIETAL HANDELAARS',
#  'JUFFROUW JOHANNA']

# %% [markdown]
# ## Predicates
# (a) Return the harbour elements that are a “destination” of the boat named “BATAVIA”.

# %%
run_xpath("/voyage/leftpage[./boatname = 'BATAVIA']/destination/harbour/text()")
# Out:
# ['Batavia', 'Batavia', 'Batavia', 'Rammekens']

# %% [markdown]
# (b) Return the voyage elements for which the boat named “BATAVIA” sailed from or to the harbour
# “Batavia”. (there are 7 such voyages)

# %%
run_xpath("/voyage[./leftpage/boatname = 'BATAVIA' and (./leftpage/harbour = 'Batavia' or ./leftpage/destination/harbour = 'Batavia')]/number/text()")
# Out:
# ['8077', '5571', '4368', '4260', '1150', '1055', '7986']

# %% [markdown]
# (c) Return the voyage elements of which the “Willem IJsbrandsz. Bontekoe” was the “master”.

# %%
run_xpath("/voyage[./leftpage/master = 'Willem IJsbrandsz. Bontekoe']/number/text()")
# Out:
# ['5169']

# %% [markdown]
# (d) A voyage element sometimes contains an element particulars with a possible follow-up voyage
# (next element) and a description of some noteworthy facts. Give the voyages that mention the “Cape of Good Hope” in their particulars (there are two such voyages).

# %%
run_xpath("/voyage[contains(./rightpage/particulars, 'Cape of Good Hope')]/number/text()")
# Out:
# ['5022', '5022']

# %% [markdown]
# ## Positions
# (a) Queries can also be used to check the correctness of the structure of a document. For example, it seems
# logical that, since each voyage was done by boat, each voyage element has a boatname descendant
# element. To check this and to inspect a possible violation, write a query that gives the first voyage
# element that has no boat name.

# %%
run_xpath("/voyage[not(./leftpage/boatname)][1]/number/text()")
# Out:
# ['8215']

# %% [markdown]
# (b) XQuery defines 13 axis steps: ‘ancestor’, ‘ancestor-or-self’, ‘attribute’, ‘child’, ‘descendant’,
# ‘descendant-or-self’, ‘following’, ‘following-sibling’, ‘namespace’, ‘parent’, ‘preceding’, ‘precedingsibling’, and ‘self’. The notations ‘.’, ‘/’ and ‘//’, are short-hands for axis-steps. Rewrite the following
# 3 queries, such that they do no longer contain short-hands:
# • doc("voc.xml")/voyage[number = "4144"]/*[4]
# • doc("voc.xml")/voyage[number = "4144"]//*[4]
# • doc("voc.xml")/voyage[number = "4144"]/descendant::*[4]

# %%
# doc("voc.xml")/voyage[number = "4144"]/*[4]
run_xpath('/child::voyage[child::number = "4144"]/child::*[4]')
# Out:
# ['<rightpage>',
#  '      <onboard>',
#  '        <total>',
#  '          <one>235</one>',
#  '          <two>17</two>',
#  '          <three>16</three>',
#  '        </total>',
#  '      </onboard>',
#  "      <particulars><next>7928</next> The following data refer to the crew of the BEEMSTER WELVAREN as well as to the crews of the DUIVENBRUG (4154), the EUROPA (4155), and the ZEEDUIN (4166): 534 seafarers, 225 soldiers, 25 craftsmen, and 5 passengers arrived at Batavia. Data concerning both the aforesaid four ships and the ASCHAT (4147), the AZIE (4148), the OVERHOUT (4151), the VOORBERG (4153), the HOLLAND (4157), the HUIS TE BIJWEG (4159), the 'T LOO (4161), the OOSTKAPELLE (4162), and the VREEBURG (4163): 2695 seafarers, 1317 soldiers, 150 craftsmen, and 34 passengers departed from the Republic or embarked at the Cape. Data referring to all above-mentioned thirteen ships as well as to the VROUWE ANTHOINETTA KOENRARDINA (4145), the JUNO (4146), and the FOREEST (4150): 19 seafarers, 13 soldiers, and 2 craftsmen died at Porto Prayo, S. Tiago; 25 men deserted; at the Cape 554 seafarers, 357 soldiers, 30 craftsmen, and 15 passengers disembarked; during the voyage 496 seafarers, 410 soldiers, 61 craftsmen, and 6 passengers died.</particulars>",
#  '    </rightpage>']

# %%
# doc("voc.xml")/voyage[number = "4144"]/*[4]
run_xpath('/child::voyage[child::number = "4144"]/child::*[4]')
# Out:
# ['<rightpage>',
#  '      <onboard>',
#  '        <total>',
#  '          <one>235</one>',
#  '          <two>17</two>',
#  '          <three>16</three>',
#  '        </total>',
#  '      </onboard>',
#  "      <particulars><next>7928</next> The following data refer to the crew of the BEEMSTER WELVAREN as well as to the crews of the DUIVENBRUG (4154), the EUROPA (4155), and the ZEEDUIN (4166): 534 seafarers, 225 soldiers, 25 craftsmen, and 5 passengers arrived at Batavia. Data concerning both the aforesaid four ships and the ASCHAT (4147), the AZIE (4148), the OVERHOUT (4151), the VOORBERG (4153), the HOLLAND (4157), the HUIS TE BIJWEG (4159), the 'T LOO (4161), the OOSTKAPELLE (4162), and the VREEBURG (4163): 2695 seafarers, 1317 soldiers, 150 craftsmen, and 34 passengers departed from the Republic or embarked at the Cape. Data referring to all above-mentioned thirteen ships as well as to the VROUWE ANTHOINETTA KOENRARDINA (4145), the JUNO (4146), and the FOREEST (4150): 19 seafarers, 13 soldiers, and 2 craftsmen died at Porto Prayo, S. Tiago; 25 men deserted; at the Cape 554 seafarers, 357 soldiers, 30 craftsmen, and 15 passengers disembarked; during the voyage 496 seafarers, 410 soldiers, 61 craftsmen, and 6 passengers died.</particulars>",
#  '    </rightpage>']

# %%
# doc("voc.xml")/voyage[number = "4144"]//*[4]
run_xpath('/child::voyage[child::number = "4144"]/descendant-or-self::*[4]')
# Out:
# ['<leftpage>',
#  '      <boatname>BEEMSTER WELVAREN</boatname>',
#  '      <master>Marten Schoning</master>',
#  '      <tonnage>850</tonnage>',
#  '      <built>1770</built>',
#  '      <yard>E</yard>',
#  '      <chamber>E</chamber>',
#  '      <departure>1772-09-11</departure>',
#  '      <harbour>Texel</harbour>',
#  '      <callatcape>',
#  '        <arrival>1773-02-18</arrival>',
#  '        <departure>1773-03-07</departure>',
#  '      </callatcape>',
#  '      <destination>',
#  '        <arrival>1773-06-07</arrival>',
#  '        <harbour>Batavia</harbour>',
#  '      </destination>',
#  '    </leftpage>']

# %% [markdown]
# (c) Master “Jakob de Vries” made 16 voyages. The document does not have them in chronological order.
# Give the oldest voyage of this skipper (i.e., the first of a sequence ordered by departure).

# %%
xquery = """
let $doc := doc('Downloads/voc.xml')
for $b in $doc/VOC/voyage
where $b/leftpage/master = 'Jakob de Vries'
order by $b/leftpage/departure
return $b/leftpage/departure/text()
"""
run_xquery(xquery)
# Out:
# ['1715-04-25',
#  '1717-12-21',
#  '1725-02-03',
#  '1725-11-20',
#  '1727-11-02',
#  '1728-11-01',
#  '1757-12-19',
#  '1759-11-01',
#  '1762-06-14',
#  '1766-10-26',
#  '1767-11-24',
#  '1768-11-06',
#  '1771-06-25',
#  '1787-11-09',
#  '1789-05-21',
#  '1791-07-06']

# %% [markdown]
# ## Aggregation
# (a) In a single query, count the number of voyages in the document, count the number of boats (i.e.,
# unique boat names), and count the number of masters (i.e., unique master names. The result
# should look as follows: <totals><voyages> ... </voyages><boats> ... </boats><masters> ...
# </masters></totals>

# %%
xquery = """
let $doc := doc('Downloads/voc.xml')
return <totals>
        <voyages>{count($doc/VOC/voyage)}</voyages>
        <boats>{count($doc/VOC/voyage/leftpage/boatname)}</boats>
        <masters>{count($doc/VOC/voyage/leftpage/master)}</masters>
       </totals>
"""
run_xquery(xquery)
# Out:
# ['<totals><voyages>8076</voyages><boats>8071</boats><masters>6887</masters></totals>']

# %% [markdown]
# (b) Many boats carried soldiers. Count how many soldiers were carried in total. (No need to known what
# the elements one, two, ... mean, so just add them all up for the answer.)

# %%
xquery = """
let $doc := doc('Downloads/voc.xml')
return sum($doc/VOC/voyage/rightpage/onboard/soldiers/*)
"""
run_xquery(xquery)
# Out:
# ['467244']

# %% [markdown]
# ## Grouping
# (a) For each master (i.e., unique master name), give his name and the number of voyages he did. (Grouping can also be done without the use of ‘group by’). The results should look as follows: <master
# name=" ... " nrofvoyages= ... "/>

# %%
xquery = """
let $doc := doc('Downloads/voc.xml')
for $voyage in $doc/VOC/voyage
let $master := $voyage/leftpage/master
where $master
group by $master
return <master name='{$master}' nrofvoyages='{count($voyage)}'/>
"""
run_xquery(xquery)
# Out:
# ['<master name="Jan Kornelis Roos" nrofvoyages="5"/>',
#  '<master name="Blankman" nrofvoyages="1"/>',
#  '<master name="Bernard Christiaan Muller" nrofvoyages="5"/>',
#  '<master name="Isaak Segon" nrofvoyages="3"/>',
#  '<master name="Asuerus Brinkman" nrofvoyages="1"/>',
#  '<master name="Pieter Kardon" nrofvoyages="4"/>',
#  '<master name="Laurens Smit" nrofvoyages="4"/>',
#  '<master name="Kornelis de Wit" nrofvoyages="4"/>',
#  '<master name="Jan Jochem Milfaart" nrofvoyages="9"/>',
#  '<master name="Pieter Six" nrofvoyages="1"/>',
#  '<master name="Joseph Bexto" nrofvoyages="1"/>',
#  '<master name="Pieter Thijssen jr." nrofvoyages="5"/>',
#  '<master name="Willem Udemans jr." nrofvoyages="4"/>',
#  '<master name="De Strale" nrofvoyages="2"/>',
#  '<master name="Scipion" nrofvoyages="1"/>',
#  '<master name="Simon Koter" nrofvoyages="7"/>',
#  '<master name="Dirk Huizing" nrofvoyages="5"/>',
#  '<master name="Ilonore Roux" nrofvoyages="1"/>',
#  '<master name="Axel Land" nrofvoyages="5"/>',
#  '<master name="Jan Meindertsz. Swaal" nrofvoyages="5"/>',
#  '<master name="Herman Volkers" nrofvoyages="2"/>',
#  '<master name="Theunis Hans Borch" nrofvoyages="2"/>',
#  '<master name="Hendrik Elders jr." nrofvoyages="3"/>',
#  '<master name="Lambert Arnout Halfman" nrofvoyages="5"/>',
#  '<master name="Thoger Abo" nrofvoyages="1"/>',
#  '<master name="Frederik Godert Wever" nrofvoyages="3"/>',
#  '<master name="Jan Montagne" nrofvoyages="3"/>',
#  '<master name="Jakob Frederiks" nrofvoyages="2"/>',
#  '<master name="Isaak Louis Bellon" nrofvoyages="1"/>',
#  '<master name="Klaas Roem" nrofvoyages="11"/>',
#  '<master name="Paulus Bast" nrofvoyages="1"/>',
#  '<master name="Swerus Vrolijk" nrofvoyages="9"/>',
#  '<master name="Jochem Bank" nrofvoyages="6"/>',
#  '<master name="Hendrik Steedsel" nrofvoyages="3"/>',
#  '<master name="Kornelis Philippus Hoek" nrofvoyages="4"/>',
#  '<master name="Herman Jakob Hulleman" nrofvoyages="4"/>',
#  '<master name="Kornelis de Boer" nrofvoyages="3"/>',
#  '<master name="Jakob Veer" nrofvoyages="6"/>',
#  '<master name="Dirk Hulsebos" nrofvoyages="2"/>',
#  '<master name="Francois Duminy" nrofvoyages="1"/>',
#  '<master name="Harme Karel Visser" nrofvoyages="4"/>',
#  '<master name="Samuel Nusker" nrofvoyages="2"/>',
#  '<master name="John Wilton" nrofvoyages="1"/>',
#  '<master name="Jakob Johan Staalkop" nrofvoyages="2"/>',
#  '<master name="Benjamin van der Spek" nrofvoyages="5"/>',
#  '<master name="Kornelis Loreim" nrofvoyages="1"/>',
#  '<master name="Wouter de Gelder" nrofvoyages="2"/>',
#  '<master name="Jan Frederik Volmer" nrofvoyages="4"/>',
#  '<master name="Gottlieb Mulder" nrofvoyages="5"/>',
#  '<master name="Gerrit Harmeyer" nrofvoyages="12"/>',
#  '<master name="Arie Kikkert" nrofvoyages="6"/>',
#  '<master name="Willem de Wijn" nrofvoyages="2"/>',
#  '<master name="Jan Frederik Zegert" nrofvoyages="1"/>',
#  '<master name="Willem Jakob Andriessen" nrofvoyages="2"/>',
#  '<master name="Kornelis van Vlaanderen" nrofvoyages="4"/>',
#  '<master name="Sijbrand Berk" nrofvoyages="3"/>',
#  '<master name="Andries Allan" nrofvoyages="1"/>',
#  '<master name="Jan Jansz. Laurits" nrofvoyages="8"/>',
#  '<master name="Pieter Harmsz." nrofvoyages="1"/>',
#  '<master name="Thijs Ketel" nrofvoyages="5"/>',
#  '<master name="Peter Jansen" nrofvoyages="4"/>',
#  '<master name="Dirk Carlberg" nrofvoyages="2"/>',
#  '<master name="Klaas Ent" nrofvoyages="4"/>',
#  '<master name="Johan Otto" nrofvoyages="1"/>',
#  '<master name="Pieter Johan Muller" nrofvoyages="2"/>',
#  '<master name="Bartholomeus Veau" nrofvoyages="3"/>',
#  '<master name="Adriaan van Katersveld" nrofvoyages="4"/>',
#  '<master name="Ane van der Giessen" nrofvoyages="1"/>',
#  '<master name="Jan Hendrik van der Linden" nrofvoyages="3"/>',
#  '<master name="Barend Jansz. Uffen" nrofvoyages="4"/>',
#  '<master name="Tijmen de Zweed" nrofvoyages="4"/>',
#  '<master name="Asmus Pieter Asmus" nrofvoyages="6"/>',
#  '<master name="Justinus Philippus Man" nrofvoyages="3"/>',
#  '<master name="Matthijs Lodewijk Heikoop" nrofvoyages="1"/>',
#  '<master name="Kornelis Kornelissen" nrofvoyages="6"/>',
#  '<master name="Kornelis de Klerk" nrofvoyages="2"/>',
#  '<master name="Jan Kraai" nrofvoyages="3"/>',
#  '<master name="Hans Klaassen" nrofvoyages="4"/>',
#  '<master name="Dirk Kornelis Plokker" nrofvoyages="2"/>',
#  '<master name="Laurens Kornelissen" nrofvoyages="3"/>',
#  '<master name="Kornelis in \'t Anker" nrofvoyages="1"/>',
#  '<master name="Christoffel Beem" nrofvoyages="4"/>',
#  '<master name="Hendrik Zwart" nrofvoyages="1"/>',
#  '<master name="Frederik Floor" nrofvoyages="1"/>',
#  '<master name="Huibert den Breem" nrofvoyages="1"/>',
#  '<master name="Pieter Modderman" nrofvoyages="4"/>',
#  '<master name="A. Arend Thobiasz." nrofvoyages="2"/>',
#  '<master name="Jan Siereveld" nrofvoyages="9"/>',
#  '<master name="Josua Felix de Zouza" nrofvoyages="1"/>',
#  '<master name="Hans Christiaan Christiaanse" nrofvoyages="4"/>',
#  '<master name="Aris van Valkenburg" nrofvoyages="2"/>',
#  '<master name="Klaas Duif" nrofvoyages="4"/>',
#  '<master name="Dirk Roem" nrofvoyages="3"/>',
#  '<master name="Daniel Kunneman" nrofvoyages="4"/>',
#  '<master name="Christiaan Zummack" nrofvoyages="5"/>',
#  '<master name="Gijshert Matthias Weitzel" nrofvoyages="1"/>',
#  '<master name="Hendrik Eduard Lodewijk van Baggen" nrofvoyages="1"/>',
#  '<master name="Dirk Peek" nrofvoyages="5"/>',
#  '<master name="Imel Edan de Vries" nrofvoyages="1"/>',
#  '<master name="Gouke Dekker van der Mieden" nrofvoyages="2"/>',
#  '<master name="Johan Bakker" nrofvoyages="2"/>',
#  '<master name="Pieter Stokbroo" nrofvoyages="3"/>',
#  '<master name="Jonas Arend" nrofvoyages="1"/>',
#  '<master name="Paulus Kroon" nrofvoyages="8"/>',
#  '<master name="Roelof Pietersz. Hoberg" nrofvoyages="3"/>',
#  '<master name="Johan Noordhoek" nrofvoyages="1"/>',
#  '<master name="Wouter Jakobsen" nrofvoyages="2"/>',
#  '<master name="Christiaan Rebel" nrofvoyages="3"/>',
#  '<master name="Hillert Volkers" nrofvoyages="3"/>',
#  '<master name="Jurriaan Raasel" nrofvoyages="1"/>',
#  '<master name="Gerrit Bruin" nrofvoyages="6"/>',
#  '<master name="Christiaan van Veerden" nrofvoyages="6"/>',
#  '<master name="Jan Everwijk Drillinger" nrofvoyages="4"/>',
#  '<master name="Willem Ferret" nrofvoyages="2"/>',
#  '<master name="Jakob Koelders" nrofvoyages="2"/>',
#  '<master name="Frans van Ewijk" nrofvoyages="4"/>',
#  '<master name="Gerrit Springer" nrofvoyages="6"/>',
#  '<master name="Olke Hendrik Andringa" nrofvoyages="5"/>',
#  '<master name="Pieter Haverkamp" nrofvoyages="3"/>',
#  '<master name="Josua de Wolf van Ieperen" nrofvoyages="3"/>',
#  '<master name="Justus Hendrik Pfeil" nrofvoyages="3"/>',
#  '<master name="Hendrik Nieuwboer" nrofvoyages="4"/>',
#  '<master name="Hendrik Mulder" nrofvoyages="5"/>',
#  '<master name="Isaak Louis de Bellon" nrofvoyages="3"/>',
#  '<master name="Hendrik Hilverduin" nrofvoyages="8"/>',
#  '<master name="Jan Frederik Raatjes" nrofvoyages="6"/>',
#  '<master name="Justinus van Gennep" nrofvoyages="4"/>',
#  '<master name="Gerrit Berg" nrofvoyages="6"/>',
#  '<master name="Joachim Ernst Wend" nrofvoyages="3"/>',
#  '<master name="Jan Stil" nrofvoyages="6"/>',
#  '<master name="Jan Abel" nrofvoyages="8"/>',
#  '<master name="Stoffel Kok" nrofvoyages="4"/>',
#  '<master name="Joost Koen" nrofvoyages="3"/>',
#  '<master name="Daniel Deune" nrofvoyages="6"/>',
#  '<master name="Pieter Helmers" nrofvoyages="3"/>',
#  '<master name="Marten Schoning" nrofvoyages="2"/>',
#  '<master name="Wopke Popta" nrofvoyages="8"/>',
#  '<master name="Johan van Voorst" nrofvoyages="8"/>',
#  '<master name="Jan Och" nrofvoyages="8"/>',
#  '<master name="Kornelis Bos" nrofvoyages="8"/>',
#  '<master name="Willem Dona" nrofvoyages="4"/>',
#  '<master name="Marten Hakker" nrofvoyages="8"/>',
#  '<master name="Michiel Kooplijn" nrofvoyages="4"/>',
#  '<master name="Michiel Hamelo" nrofvoyages="10"/>',
#  '<master name="Willem Koelbier" nrofvoyages="6"/>',
#  '<master name="J. Wellegaart" nrofvoyages="2"/>',
#  '<master name="Asmus Hendrik Sterrenberg" nrofvoyages="5"/>',
#  '<master name="Andries Bruin" nrofvoyages="2"/>',
#  '<master name="Jan Kaatman" nrofvoyages="6"/>',
#  '<master name="Johan Frederik Schuts" nrofvoyages="4"/>',
#  '<master name="Marten Pietersz. Mooy" nrofvoyages="9"/>',
#  '<master name="Leendert van Koopstad" nrofvoyages="9"/>',
#  '<master name="Jan Paardekoper" nrofvoyages="7"/>',
#  '<master name="Hendrik Willemse" nrofvoyages="8"/>',
#  '<master name="Reindert den Uil" nrofvoyages="6"/>',
#  '<master name="Pieter ten Droge" nrofvoyages="3"/>',
#  '<master name="Jan Balthus Meyer" nrofvoyages="8"/>',
#  '<master name="Hans Hansen" nrofvoyages="5"/>',
#  '<master name="Jakob de Frein" nrofvoyages="8"/>',
#  '<master name="Frederik Visser" nrofvoyages="5"/>',
#  '<master name="Andries Hansen" nrofvoyages="5"/>',
#  '<master name="Pieter Angelvorst" nrofvoyages="5"/>',
#  '<master name="Josua de Wolf van leperen" nrofvoyages="2"/>',
#  '<master name="Michiel Hendrik Wunder" nrofvoyages="4"/>',
#  '<master name="George Steendekker" nrofvoyages="1"/>',
#  '<master name="Jakob Hendrik Johansen" nrofvoyages="4"/>',
#  '<master name="Pieter Verkerk" nrofvoyages="3"/>',
#  '<master name="Frederik Wielard" nrofvoyages="10"/>',
#  '<master name="Christiaan Blom" nrofvoyages="7"/>',
#  '<master name="Arend van der Deuren" nrofvoyages="10"/>',
#  '<master name="Lambert Arnout Hallman" nrofvoyages="2"/>',
#  '<master name="Damiaan Hugo Staring" nrofvoyages="2"/>',
#  '<master name="Pieter van Prooien" nrofvoyages="9"/>',
#  '<master name="Gerrit Evertsz. Popta" nrofvoyages="4"/>',
#  '<master name="Kornelis Pietersen" nrofvoyages="16"/>',
#  '<master name="Pieter Sijbrandsz. Flout" nrofvoyages="4"/>',
#  '<master name="Jan Moorland" nrofvoyages="9"/>',
#  '<master name="Pieter Thomasz." nrofvoyages="2"/>',
#  '<master name="Christiaan Andries Spin" nrofvoyages="6"/>',
#  '<master name="Frederik Papegaai" nrofvoyages="5"/>',
#  '<master name="Frederik Donckquart" nrofvoyages="1"/>',
#  '<master name="Gerrit ten Sunder" nrofvoyages="4"/>',
#  '<master name="Jan van Eysden" nrofvoyages="6"/>',
#  '<master name="Jurriaan Verburg" nrofvoyages="6"/>',
#  '<master name="Karsten Eggers" nrofvoyages="4"/>',
#  '<master name="Abraham van der Weide" nrofvoyages="4"/>',
#  '<master name="Karel Philip Kassel" nrofvoyages="2"/>',
#  '<master name="Thomas de Beukelaar" nrofvoyages="4"/>',
#  '<master name="Pieter van der Weert" nrofvoyages="3"/>',
#  '<master name="Willem Vos van Overstraten" nrofvoyages="2"/>',
#  '<master name="Andries Lint" nrofvoyages="7"/>',
#  '<master name="Pieter Andriesz." nrofvoyages="6"/>',
#  '<master name="Michiel Hendrik Kerke" nrofvoyages="5"/>',
#  '<master name="Steven Booms" nrofvoyages="4"/>',
#  '<master name="Roelof Schot" nrofvoyages="2"/>',
#  '<master name="Kornelis Brouwer" nrofvoyages="5"/>',
#  '<master name="Gerrit van der Gracht" nrofvoyages="3"/>',
#  '<master name="Jakob \'t Hart" nrofvoyages="3"/>',
#  '<master name="Michiel Godfried Lehman" nrofvoyages="8"/>',
#  '<master name="Johan Nikolaas Herault" nrofvoyages="3"/>',
#  '<master name="Jan Rondekrans" nrofvoyages="3"/>',
#  '<master name="Kornelis Kuiper" nrofvoyages="10"/>',
#  '<master name="Arend Willemse" nrofvoyages="4"/>',
#  '<master name="Simon Bot" nrofvoyages="6"/>',
#  '<master name="Anthonie de Jong" nrofvoyages="3"/>',
#  '<master name="Marten Laban" nrofvoyages="1"/>',
#  '<master name="Frederik Kelger" nrofvoyages="9"/>',
#  '<master name="Johan Hendriksz." nrofvoyages="3"/>',
#  '<master name="Hendrik de Haard" nrofvoyages="4"/>',
#  '<master name="Johan Splinter Stavorinus" nrofvoyages="5"/>',
#  '<master name="Jan Verheke" nrofvoyages="2"/>',
#  '<master name="Wouter Macquelin" nrofvoyages="2"/>',
#  '<master name="Jakob de Bruin" nrofvoyages="2"/>',
#  '<master name="Klaas Ariensz." nrofvoyages="8"/>',
#  '<master name="Thijs Fierman" nrofvoyages="6"/>',
#  '<master name="Johan Sigismund Hoeve" nrofvoyages="7"/>',
#  '<master name="Thomas van Wagtendonk" nrofvoyages="4"/>',
#  '<master name="Hendrik Jakob Beeld" nrofvoyages="3"/>',
#  '<master name="Thomas Brunel" nrofvoyages="2"/>',
#  '<master name="H. Huurman" nrofvoyages="1"/>',
#  '<master name="Willem Silvester" nrofvoyages="4"/>',
#  '<master name="Jan van Dalen" nrofvoyages="6"/>',
#  '<master name="Jan Berghuis" nrofvoyages="2"/>',
#  '<master name="Willem van Braam" nrofvoyages="6"/>',
#  '<master name="Abraham in \'t Anker" nrofvoyages="5"/>',
#  '<master name="Pieter Fruit" nrofvoyages="4"/>',
#  '<master name="Jan Hendriksz." nrofvoyages="2"/>',
#  '<master name="Pieter Clement" nrofvoyages="5"/>',
#  '<master name="Kornelis van Brattem" nrofvoyages="3"/>',
#  '<master name="Jan Canvas" nrofvoyages="3"/>',
#  '<master name="Jan Karel Schacht" nrofvoyages="2"/>',
#  '<master name="Lodewijk Thomassen" nrofvoyages="2"/>',
#  '<master name="Dirk Wagtels" nrofvoyages="6"/>',
#  '<master name="Jakob de Vries" nrofvoyages="16"/>',
#  '<master name="Abel Barber" nrofvoyages="3"/>',
#  '<master name="Antonie Leertouwer" nrofvoyages="1"/>',
#  '<master name="Frans Overzee" nrofvoyages="3"/>',
#  '<master name="Jakob Boekhout" nrofvoyages="7"/>',
#  '<master name="Arie Arkebout" nrofvoyages="6"/>',
#  '<master name="Abraham van Leeuwen" nrofvoyages="3"/>',
#  '<master name="Barend Rust" nrofvoyages="3"/>',
#  '<master name="Laurens Helmstrom" nrofvoyages="7"/>',
#  '<master name="Albert Kikkert" nrofvoyages="5"/>',
#  '<master name="Arie Fransz." nrofvoyages="2"/>',
#  '<master name="Bernard Hulleman" nrofvoyages="4"/>',
#  '<master name="Jacob de Frein" nrofvoyages="1"/>',
#  '<master name="Josua Hartman" nrofvoyages="4"/>',
#  '<master name="Kornelis van der Stam" nrofvoyages="6"/>',
#  '<master name="Jakob Wiebe" nrofvoyages="13"/>',
#  '<master name="Pieter de Leur" nrofvoyages="6"/>',
#  '<master name="Jochem Hendrik Dodendorp" nrofvoyages="8"/>',
#  '<master name="Laurens Houtepen" nrofvoyages="7"/>',
#  '<master name="Lieve van Rentergem" nrofvoyages="2"/>',
#  '<master name="Willem Groeve" nrofvoyages="2"/>',
#  '<master name="Jan Hendrik Vogelaar" nrofvoyages="1"/>',
#  '<master name="Hendrik Andries Tieding" nrofvoyages="4"/>',
#  '<master name="Gerrit de Waal" nrofvoyages="2"/>',
#  '<master name="Michiel Wargijn" nrofvoyages="1"/>',
#  '<master name="Abraham van der Weiden" nrofvoyages="1"/>',
#  '<master name="Johannes van Boom" nrofvoyages="4"/>',
#  '<master name="Aldert Aldertsz." nrofvoyages="2"/>',
#  '<master name="Volkert Groeneweg van Oudshoom" nrofvoyages="3"/>',
#  '<master name="Erasmus de Vries" nrofvoyages="3"/>',
#  '<master name="Klaas Stuiver" nrofvoyages="7"/>',
#  '<master name="Anthonie de long" nrofvoyages="1"/>',
#  '<master name="Teunis van Brattem" nrofvoyages="1"/>',
#  '<master name="Gerrit Bartels" nrofvoyages="2"/>',
#  '<master name="Pieter Breugel" nrofvoyages="2"/>',
#  '<master name="Markus Tetting" nrofvoyages="7"/>',
#  '<master name="Nikolaas Herault" nrofvoyages="1"/>',
#  '<master name="Huibert van der Kneu" nrofvoyages="2"/>',
#  '<master name="Jurriaan Molensteen" nrofvoyages="7"/>',
#  '<master name="George Jakob Meyer" nrofvoyages="3"/>',
#  '<master name="Isaak van den Berg" nrofvoyages="6"/>',
#  '<master name="Simon van Dalen" nrofvoyages="5"/>',
#  '<master name="Anthonie Leertouwer" nrofvoyages="6"/>',
#  '<master name="Jan Schellinger" nrofvoyages="7"/>',
#  '<master name="Jan Beys" nrofvoyages="3"/>',
#  '<master name="Daniel Nieman" nrofvoyages="4"/>',
#  '<master name="Edmond Collier" nrofvoyages="1"/>',
#  '<master name="Jonas Hendriksz." nrofvoyages="1"/>',
#  '<master name="Pieter Schoneman" nrofvoyages="6"/>',
#  '<master name="Adriaan de Graaf+" nrofvoyages="1"/>',
#  '<master name="Simon de Graaf" nrofvoyages="5"/>',
#  '<master name="Hendrik Worms" nrofvoyages="3"/>',
#  '<master name="Pieter Broman" nrofvoyages="5"/>',
#  '<master name="Johan Muller" nrofvoyages="1"/>',
#  '<master name="Jan Holst" nrofvoyages="1"/>',
#  '<master name="Dirk van Maastricht" nrofvoyages="6"/>',
#  '<master name="Christiaan Hagerop" nrofvoyages="6"/>',
#  '<master name="Hans Bruns" nrofvoyages="3"/>',
#  '<master name="Jan de la Nooye" nrofvoyages="1"/>',
#  '<master name="Jan Stewer" nrofvoyages="1"/>',
#  '<master name="Volkert Groeneweg van Oudshoorn" nrofvoyages="2"/>',
#  '<master name="Adriaan van den Boer" nrofvoyages="7"/>',
#  '<master name="Jakob Reysik" nrofvoyages="6"/>',
#  '<master name="Bartholomeus Bigom" nrofvoyages="3"/>',
#  '<master name="Willem Everdingen van der Nieuwpoort" nrofvoyages="2"/>',
#  '<master name="Hans Kornelisz." nrofvoyages="5"/>',
#  '<master name="Jan Spek" nrofvoyages="4"/>',
#  '<master name="Kornelis Nannings" nrofvoyages="8"/>',
#  '<master name="Leendert van der Linden" nrofvoyages="3"/>',
#  '<master name="Kornelis Stuurmans" nrofvoyages="1"/>',
#  '<master name="Bartholomeus Schut" nrofvoyages="5"/>',
#  '<master name="Simon Rood" nrofvoyages="3"/>',
#  '<master name="Jan van der Zee" nrofvoyages="1"/>',
#  '<master name="Pieter Boot" nrofvoyages="2"/>',
#  '<master name="Willem Vrucht" nrofvoyages="9"/>',
#  '<master name="Holland" nrofvoyages="1"/>',
#  '<master name="Willem Klump" nrofvoyages="9"/>',
#  '<master name="Adriaan Arkebout" nrofvoyages="1"/>',
#  '<master name="Pieter Matthijs Joele" nrofvoyages="5"/>',
#  '<master name="Pieter Visser" nrofvoyages="16"/>',
#  '<master name="Leendert Kouw" nrofvoyages="3"/>',
#  '<master name="Kornelis de Jonge" nrofvoyages="7"/>',
#  '<master name="Jan Doensen" nrofvoyages="2"/>',
#  '<master name="Gillis Paterson" nrofvoyages="1"/>',
#  '<master name="Jan Frederik Schrijver" nrofvoyages="4"/>',
#  '<master name="Willem Hoogland" nrofvoyages="5"/>',
#  '<master name="Steven Lodewijk de Lill" nrofvoyages="3"/>',
#  '<master name="Jan Mulder" nrofvoyages="5"/>',
#  '<master name="Karel Koster" nrofvoyages="1"/>',
#  '<master name="George Christiaan Honsdorp" nrofvoyages="3"/>',
#  '<master name="Jan Willem Munts" nrofvoyages="2"/>',
#  '<master name="Jan Bernard Schaper" nrofvoyages="2"/>',
#  '<master name="Louis de Jonge" nrofvoyages="3"/>',
#  '<master name="Justus Baak" nrofvoyages="2"/>',
#  '<master name="Jan Zacharias Nauwman" nrofvoyages="2"/>',
#  '<master name="Coenraad Dirk Wolk" nrofvoyages="2"/>',
#  '<master name="Herman de Kool" nrofvoyages="4"/>',
#  '<master name="Christiaan Hansen" nrofvoyages="3"/>',
#  '<master name="Huibrecht van der Kneu" nrofvoyages="5"/>',
#  '<master name="Simon Smit" nrofvoyages="2"/>',
#  '<master name="Jan Sluiskens" nrofvoyages="5"/>',
#  '<master name="Reindert Dijkveld" nrofvoyages="1"/>',
#  '<master name="Hendrik Winkelman ." nrofvoyages="1"/>',
#  '<master name="Hieronymus Jongenberg" nrofvoyages="1"/>',
#  '<master name="Adriaan Bertrand" nrofvoyages="2"/>',
#  '<master name="Dirk Pietersz." nrofvoyages="3"/>',
#  '<master name="Kornelis Boomgaard" nrofvoyages="1"/>',
#  '<master name="Albert Verzaat" nrofvoyages="2"/>',
#  '<master name="Jan Hoyer" nrofvoyages="2"/>',
#  '<master name="Augustinus Heynenberg" nrofvoyages="2"/>',
#  '<master name="Leendert Marinus Kouw" nrofvoyages="1"/>',
#  '<master name="Pieter van Kronenburg" nrofvoyages="1"/>',
#  '<master name="Samuel Wanjon" nrofvoyages="3"/>',
#  '<master name="Frans Lodder" nrofvoyages="1"/>',
#  '<master name="Kornelis Eike" nrofvoyages="4"/>',
#  '<master name="Hendrik Visser" nrofvoyages="5"/>',
#  '<master name="Marten van der Meer" nrofvoyages="2"/>',
#  '<master name="Willem Kramer" nrofvoyages="3"/>',
#  '<master name="Dirk Took" nrofvoyages="7"/>',
#  '<master name="Kornelis van Zwanenburg" nrofvoyages="5"/>',
#  '<master name="Maarten de Vos" nrofvoyages="4"/>',
#  '<master name="Klaas Droogsteen" nrofvoyages="3"/>',
#  '<master name="Jan de Wit" nrofvoyages="13"/>',
#  '<master name="Willem \'t Hoen" nrofvoyages="7"/>',
#  '<master name="Kornelis Quack" nrofvoyages="5"/>',
#  '<master name="Pieter de Wayer de la Rue" nrofvoyages="1"/>',
#  '<master name="Josias Ruts" nrofvoyages="2"/>',
#  '<master name="Hendrik Booms" nrofvoyages="4"/>',
#  '<master name="Maarten Wout" nrofvoyages="1"/>',
#  '<master name="Dirk van der Schilde" nrofvoyages="7"/>',
#  '<master name="Jakob Leertouwer" nrofvoyages="3"/>',
#  '<master name="Martin Haringman" nrofvoyages="6"/>',
#  '<master name="Jan de Wever" nrofvoyages="3"/>',
#  '<master name="Jan Willemsz. van den Briel" nrofvoyages="5"/>',
#  '<master name="Pieter Jongedijk" nrofvoyages="2"/>',
#  '<master name="Herman Laurier" nrofvoyages="4"/>',
#  '<master name="Hendrik Taal" nrofvoyages="7"/>',
#  '<master name="Jakob Kolom" nrofvoyages="2"/>',
#  '<master name="Adriaan Roos" nrofvoyages="1"/>',
#  '<master name="Jan Martens" nrofvoyages="3"/>',
#  '<master name="Pieter Tornboom" nrofvoyages="4"/>',
#  '<master name="Gerrit Bot" nrofvoyages="4"/>',
#  '<master name="Martin Lop" nrofvoyages="4"/>',
#  '<master name="Kornelis Leempoel" nrofvoyages="3"/>',
#  '<master name="Gijsbert Bonekamp" nrofvoyages="6"/>',
#  '<master name="Kornelis Trappel" nrofvoyages="4"/>',
#  '<master name="Jurriaan Hinst" nrofvoyages="1"/>',
#  '<master name="Paulus Engelaar" nrofvoyages="3"/>',
#  '<master name="Hendrik Westermeer" nrofvoyages="1"/>',
#  '<master name="Jakob van Wies" nrofvoyages="1"/>',
#  '<master name="Abraham Zwart" nrofvoyages="7"/>',
#  '<master name="Kornelis de Nijs" nrofvoyages="5"/>',
#  '<master name="Jochem Beek" nrofvoyages="5"/>',
#  '<master name="Herman Zoet" nrofvoyages="5"/>',
#  '<master name="Leendert van Dijk" nrofvoyages="6"/>',
#  '<master name="Michiel van Son" nrofvoyages="6"/>',
#  '<master name="Jan du Riets" nrofvoyages="5"/>',
#  '<master name="Jakob Greef" nrofvoyages="3"/>',
#  '<master name="Otto Freudenfeld" nrofvoyages="3"/>',
#  '<master name="Leendert de Bruin" nrofvoyages="3"/>',
#  '<master name="Adriaan de Graaf" nrofvoyages="8"/>',
#  '<master name="Kornelis Vis" nrofvoyages="4"/>',
#  '<master name="Bastiaan Verdoes" nrofvoyages="10"/>',
#  '<master name="Frederik Jan Paul Honsdorp" nrofvoyages="1"/>',
#  '<master name="Govert van Welle" nrofvoyages="3"/>',
#  '<master name="Hubertus van der Linde" nrofvoyages="1"/>',
#  '<master name="Pieter Lund" nrofvoyages="1"/>',
#  '<master name="Willem de Wijs" nrofvoyages="11"/>',
#  '<master name="Pieter Lichthart" nrofvoyages="3"/>',
#  '<master name="Willem van der Heyden" nrofvoyages="6"/>',
#  '<master name="Jochem Outjes" nrofvoyages="5"/>',
#  '<master name="Klaas Andersen" nrofvoyages="5"/>',
#  '<master name="Willem van Mensburg" nrofvoyages="5"/>',
#  '<master name="Kornelis Jurriaansz." nrofvoyages="4"/>',
#  '<master name="Jochem Aldertsz. Tamike" nrofvoyages="1"/>',
#  '<master name="Gillis Dabijn" nrofvoyages="3"/>',
#  '<master name="Thijl Jansz. Thijling" nrofvoyages="2"/>',
#  '<master name="Jean de la Voie" nrofvoyages="5"/>',
#  '<master name="Arneus Lodewijk Berting" nrofvoyages="2"/>',
#  '<master name="Abraham Haring" nrofvoyages="3"/>',
#  '<master name="Gerrit Reyndertsz. Vos" nrofvoyages="10"/>',
#  '<master name="Simon de Groot" nrofvoyages="7"/>',
#  '<master name="Frederik Schouten" nrofvoyages="4"/>',
#  '<master name="Jan Kakelaar" nrofvoyages="4"/>',
#  '<master name="Jakob Buis" nrofvoyages="3"/>',
#  '<master name="Frederik Jansz. van Winsum" nrofvoyages="2"/>',
#  '<master name="Willem Marreeuw" nrofvoyages="3"/>',
#  '<master name="Pieter Tomboom" nrofvoyages="1"/>',
#  '<master name="Jan Diederik Morel" nrofvoyages="3"/>',
#  '<master name="Hendrik van Oudheusden" nrofvoyages="3"/>',
#  '<master name="Arie van der Meer" nrofvoyages="2"/>',
#  '<master name="David van Elteren" nrofvoyages="7"/>',
#  '<master name="Kornelis Zwanenburg" nrofvoyages="2"/>',
#  '<master name="Jan Tuinman" nrofvoyages="3"/>',
#  '<master name="Herman Schutte" nrofvoyages="6"/>',
#  '<master name="Jean Belleveau" nrofvoyages="4"/>',
#  '<master name="Pieter van Onkhuizen" nrofvoyages="2"/>',
#  '<master name="Gerrit de Leeuw" nrofvoyages="3"/>',
#  '<master name="Maarten van der Meer" nrofvoyages="5"/>',
#  '<master name="Leendert Bonekamp" nrofvoyages="2"/>',
#  '<master name="Kornelis Mangelaar" nrofvoyages="2"/>',
#  '<master name="Paulus Lindenberg" nrofvoyages="2"/>',
#  '<master name="Hendrik Volkers" nrofvoyages="4"/>',
#  '<master name="Huibert Tiebout" nrofvoyages="8"/>',
#  '<master name="Klaas van den Hoed" nrofvoyages="3"/>',
#  '<master name="Huibert Vijs" nrofvoyages="3"/>',
#  '<master name="Jan Mijsters" nrofvoyages="6"/>',
#  '<master name="Jan Hugo Captijn" nrofvoyages="5"/>',
#  '<master name="Bastiaan Mol" nrofvoyages="9"/>',
#  '<master name="Leendert de Bruyn" nrofvoyages="1"/>',
#  '<master name="Hendrik de Ruyter" nrofvoyages="5"/>',
#  '<master name="Pieter Jellesz." nrofvoyages="5"/>',
#  '<master name="Jan de Jong" nrofvoyages="5"/>',
#  '<master name="Jan Christoffel Tiede" nrofvoyages="1"/>',
#  '<master name="Willem van Westrenen" nrofvoyages="3"/>',
#  '<master name="Ficco Eybo van Rheede" nrofvoyages="2"/>',
#  '<master name="Floris Smit" nrofvoyages="2"/>',
#  '<master name="Jan de Zee" nrofvoyages="4"/>',
#  '<master name="Dirk Quast" nrofvoyages="5"/>',
#  '<master name="Jan Verhagen" nrofvoyages="2"/>',
#  '<master name="Dirk Verduin" nrofvoyages="3"/>',
#  '<master name="Otto van Dam" nrofvoyages="3"/>',
#  '<master name="Wijnand Meurs" nrofvoyages="3"/>',
#  '<master name="Jakob Laurens" nrofvoyages="1"/>',
#  '<master name="Johannes Brand" nrofvoyages="1"/>',
#  '<master name="Nikolaas van Ewijk" nrofvoyages="3"/>',
#  '<master name="Marten den Breems" nrofvoyages="2"/>',
#  '<master name="Jan van Schutterop+" nrofvoyages="1"/>',
#  '<master name="Laurens Siewertsz." nrofvoyages="2"/>',
#  '<master name="Hendrik Bommer" nrofvoyages="3"/>',
#  '<master name="Pieter Zwanendrecht" nrofvoyages="6"/>',
#  '<master name="Pieter Sluis" nrofvoyages="7"/>',
#  '<master name="Meindert de Beer" nrofvoyages="5"/>',
#  '<master name="Paulus Pieman" nrofvoyages="4"/>',
#  '<master name="Kornelis Stevens" nrofvoyages="3"/>',
#  '<master name="Nikolaas Jongma" nrofvoyages="1"/>',
#  '<master name="Jan Reynders" nrofvoyages="4"/>',
#  '<master name="Jan Bijland" nrofvoyages="7"/>',
#  '<master name="Jan de Boer" nrofvoyages="5"/>',
#  '<master name="Michiel Keizer" nrofvoyages="11"/>',
#  '<master name="Kornelis Booys" nrofvoyages="3"/>',
#  '<master name="Boudewijn Immers" nrofvoyages="4"/>',
#  '<master name="Frans Gassels" nrofvoyages="2"/>',
#  '<master name="Jurriaan Koperslager" nrofvoyages="2"/>',
#  '<master name="Anthonie Uiterschouw" nrofvoyages="5"/>',
#  '<master name="Nanning Broeder" nrofvoyages="4"/>',
#  '<master name="Barend de Bruin" nrofvoyages="4"/>',
#  '<master name="Jan van Ingen" nrofvoyages="6"/>',
#  '<master name="Herman Quinje" nrofvoyages="3"/>',
#  '<master name="Christiaan Andriesz." nrofvoyages="1"/>',
#  '<master name="Douwe Jansz. Mout" nrofvoyages="3"/>',
#  '<master name="Hendrik Gerritsz." nrofvoyages="2"/>',
#  '<master name="Christoffel Blom" nrofvoyages="4"/>',
#  '<master name="Jan van Arras" nrofvoyages="2"/>',
#  '<master name="Pieter Krook" nrofvoyages="2"/>',
#  '<master name="Jakob Verleng" nrofvoyages="9"/>',
#  '<master name="Dirk Wolter van Nimwegen" nrofvoyages="2"/>',
#  '<master name="Pieter Lakeman" nrofvoyages="2"/>',
#  '<master name="Roelof Blok" nrofvoyages="3"/>',
#  '<master name="Willem Houthuizen" nrofvoyages="7"/>',
#  '<master name="Kornelis Kroon" nrofvoyages="5"/>',
#  '<master name="Jakob Pols" nrofvoyages="3"/>',
#  '<master name="Gerrit Blauwpot" nrofvoyages="3"/>',
#  '<master name="Jakob van Banken" nrofvoyages="5"/>',
#  '<master name="Kornelis Bommer" nrofvoyages="2"/>',
#  '<master name="Gozewijn de Vos" nrofvoyages="5"/>',
#  '<master name="Jan Elswout" nrofvoyages="4"/>',
#  '<master name="Arie Verdoes" nrofvoyages="5"/>',
#  '<master name="Jan Raay" nrofvoyages="2"/>',
#  '<master name="Jakob van Duinen" nrofvoyages="5"/>',
#  '<master name="Willem van Eyk" nrofvoyages="4"/>',
#  '<master name="Daniel Udemans" nrofvoyages="3"/>',
#  '<master name="Jan Tobias Toon" nrofvoyages="6"/>',
#  '<master name="Christiaan Boord" nrofvoyages="3"/>',
#  '<master name="Hendrik Westerbeek" nrofvoyages="5"/>',
#  '<master name="Jan Albertsz." nrofvoyages="1"/>',
#  '<master name="Leendert Jongebroer" nrofvoyages="3"/>',
#  '<master name="Joost Anker" nrofvoyages="3"/>',
#  '<master name="Jan van Heemstede" nrofvoyages="6"/>',
#  '<master name="Dirk Zomerman" nrofvoyages="3"/>',
#  '<master name="Dirk van der Poel" nrofvoyages="2"/>',
#  '<master name="Gerrit van der Tolle" nrofvoyages="6"/>',
#  '<master name="Koenraad van der Poet" nrofvoyages="1"/>',
#  '<master name="Jan Kelder" nrofvoyages="5"/>',
#  '<master name="Arie van Veurden" nrofvoyages="4"/>',
#  '<master name="Willem Vroom" nrofvoyages="7"/>',
#  '<master name="Harke Zeres" nrofvoyages="5"/>',
#  '<master name="Hendrik Detering" nrofvoyages="1"/>',
#  '<master name="Willem Hendriksz. van Roffe" nrofvoyages="4"/>',
#  '<master name="Dominikus Wormhout" nrofvoyages="3"/>',
#  '<master name="Kornelis Walle" nrofvoyages="1"/>',
#  '<master name="Kornelis van Velden" nrofvoyages="3"/>',
#  '<master name="Jakob Popta" nrofvoyages="4"/>',
#  '<master name="Jan Jorisz." nrofvoyages="2"/>',
#  '<master name="Jan Luders" nrofvoyages="2"/>',
#  '<master name="Gerrit Munt" nrofvoyages="3"/>',
#  '<master name="Frans de Put" nrofvoyages="3"/>',
#  '<master name="Samuel Hendriksz." nrofvoyages="5"/>',
#  '<master name="Hendrik Bossen" nrofvoyages="4"/>',
#  '<master name="Jan Berkmans" nrofvoyages="2"/>',
#  '<master name="Kornelis van Marie" nrofvoyages="1"/>',
#  '<master name="Daniel Tuineman" nrofvoyages="2"/>',
#  '<master name="Frans van Nek" nrofvoyages="3"/>',
#  '<master name="Jan van Thiel" nrofvoyages="7"/>',
#  '<master name="Hendrik van Raa" nrofvoyages="4"/>',
#  '<master name="Jan Govaarts" nrofvoyages="7"/>',
#  '<master name="Reinier Brugman" nrofvoyages="5"/>',
#  '<master name="Jan van Schutterop" nrofvoyages="3"/>',
#  '<master name="Gerrit Leenderts+" nrofvoyages="1"/>',
#  '<master name="Pieter Korver" nrofvoyages="5"/>',
#  '<master name="Pieter Kouderk" nrofvoyages="3"/>',
#  '<master name="Mattheus Feris du Rietz" nrofvoyages="3"/>',
#  '<master name="Frederik Hendrik Schouten" nrofvoyages="1"/>',
#  '<master name="&#xA;Jan. de Jong&#xA;" nrofvoyages="1"/>',
#  '<master name="N. Muller" nrofvoyages="1"/>',
#  '<master name="Bastiaan Koolmans" nrofvoyages="2"/>',
#  '<master name="Usbrand Moens" nrofvoyages="3"/>',
#  '<master name="Huyg Kuyper" nrofvoyages="1"/>',
#  '<master name="Adriaan Cats" nrofvoyages="4"/>',
#  '<master name="Pieter van Hoorn" nrofvoyages="3"/>',
#  '<master name="Jurriaan Wolbergen" nrofvoyages="3"/>',
#  '<master name="Willem Schul" nrofvoyages="2"/>',
#  '<master name="Hendrik Hessing" nrofvoyages="4"/>',
#  '<master name="Adriaan Pool" nrofvoyages="2"/>',
#  '<master name="Adriaan Katersveld" nrofvoyages="1"/>',
#  '<master name="Adriaan Maarseveen" nrofvoyages="1"/>',
#  '<master name="Hendrik van Beek" nrofvoyages="3"/>',
#  '<master name="Jan Olhof" nrofvoyages="6"/>',
#  '<master name="Klaas Keuken" nrofvoyages="5"/>',
#  '<master name="J. A. van der Putten" nrofvoyages="2"/>',
#  '<master name="Gerard Ewoud Overbeek" nrofvoyages="2"/>',
#  '<master name="Jan Nikolaas Kroese" nrofvoyages="1"/>',
#  '<master name="Kersje Hillebrandsz." nrofvoyages="2"/>',
#  '<master name="Hillebrand van Uijen" nrofvoyages="6"/>',
#  '<master name="Arnold Rogge" nrofvoyages="2"/>',
#  '<master name="Gottlieb Havenstein" nrofvoyages="1"/>',
#  '<master name="Ulke Barendsz." nrofvoyages="4"/>',
#  '<master name="Diedrich Wiese" nrofvoyages="1"/>',
#  '<master name="Willem Kol" nrofvoyages="1"/>',
#  '<master name="Frederik Markt" nrofvoyages="2"/>',
#  '<master name="Jan Workelijk de Wijs" nrofvoyages="1"/>',
#  '<master name="Karel Jakob Brugman" nrofvoyages="3"/>',
#  '<master name="Francois Moser" nrofvoyages="4"/>',
#  '<master name="George Philip Gas" nrofvoyages="4"/>',
#  '<master name="Gerard Adriaan van Velsen" nrofvoyages="2"/>',
#  '<master name="Kornelis Adriaansz" nrofvoyages="1"/>',
#  '<master name="Arie Smitskamp" nrofvoyages="2"/>',
#  '<master name="Anthonie Franciscus Steffers" nrofvoyages="6"/>',
#  '<master name="Erland Nicolaus Abo" nrofvoyages="1"/>',
#  '<master name="Jan Jobst Droop" nrofvoyages="3"/>',
#  '<master name="Hidde Bok" nrofvoyages="2"/>',
#  '<master name="Daniel Hendriks" nrofvoyages="3"/>',
#  '<master name="Jakob Zoeteman" nrofvoyages="4"/>',
#  '<master name="Jurriaan Kornelis Koertse" nrofvoyages="2"/>',
#  '<master name="Jakob Sem" nrofvoyages="2"/>',
#  '<master name="Wiggert Molenaar" nrofvoyages="2"/>',
#  '<master name="Simon Laurentius" nrofvoyages="4"/>',
#  '<master name="Arie Simonsz. Koek" nrofvoyages="4"/>',
#  '<master name="Jan Arendsz." nrofvoyages="7"/>',
#  '<master name="Gerrit Scheler" nrofvoyages="3"/>',
#  '<master name="Albert Tjerksz." nrofvoyages="2"/>',
#  '<master name="Theunis Groen" nrofvoyages="1"/>',
#  '<master name="Roelof Bengtson" nrofvoyages="2"/>',
#  '<master name="A. H. Christiaansz." nrofvoyages="1"/>',
#  '<master name="Pieter van Aarson" nrofvoyages="2"/>',
#  '<master name="Daniel Correch" nrofvoyages="3"/>',
#  '<master name="Kornelis van Eps" nrofvoyages="2"/>',
#  '<master name="Jan &#xA;Roelofsz. de Groot&#xA;" nrofvoyages="1"/>',
#  '<master name="Johan Koenraad Knot" nrofvoyages="2"/>',
#  '<master name="Jakob Meyer" nrofvoyages="2"/>',
#  '<master name="Christiaan de Cerf" nrofvoyages="2"/>',
#  '<master name="Lodewijk Willem van Rossum" nrofvoyages="4"/>',
#  '<master name="Kornelis van Deventer" nrofvoyages="4"/>',
#  '<master name="Albert Coblijn" nrofvoyages="1"/>',
#  '<master name="Petrus Stephanus Buissine" nrofvoyages="2"/>',
#  '<master name="Philip Hendrik de Haard" nrofvoyages="1"/>',
#  '<master name="Joost Masson" nrofvoyages="1"/>',
#  '<master name="Pieter Mallet jr." nrofvoyages="2"/>',
#  '<master name="Gerrit Esman" nrofvoyages="4"/>',
#  '<master name="Herman Petrus" nrofvoyages="1"/>',
#  '<master name="Ditmar Smit" nrofvoyages="2"/>',
#  '<master name="Anton Christian von Fleischer" nrofvoyages="2"/>',
#  '<master name="Roelof Jurgen Erdrop" nrofvoyages="2"/>',
#  '<master name="Jan Anthonie Lubben" nrofvoyages="3"/>',
#  '<master name="Hendrik Anthonie Stoete" nrofvoyages="3"/>',
#  '<master name="Jakob Soetemans" nrofvoyages="2"/>',
#  '<master name="Pieter Teteris" nrofvoyages="1"/>',
#  '<master name="Barend Sterk" nrofvoyages="3"/>',
#  '<master name="Marinus van Vlaanderen" nrofvoyages="2"/>',
#  '<master name="Kornelis Willemsen" nrofvoyages="1"/>',
#  '<master name="Hendrik Spijkerman" nrofvoyages="1"/>',
#  '<master name="Swerus Magnus Cederborg" nrofvoyages="3"/>',
#  '<master name="Anthonie van Rijn" nrofvoyages="2"/>',
#  '<master name="Dinant Visser" nrofvoyages="1"/>',
#  '<master name="Hans Barendse" nrofvoyages="3"/>',
#  '<master name="Gottlieb Jager" nrofvoyages="3"/>',
#  '<master name="Dirk Muller" nrofvoyages="2"/>',
#  '<master name="Gijsbert Matthias Weitzel" nrofvoyages="1"/>',
#  '<master name="Johan van der Plas" nrofvoyages="2"/>',
#  '<master name="Kornelis Koman" nrofvoyages="1"/>',
#  '<master name="Andries Maankop" nrofvoyages="3"/>',
#  '<master name="Jan Koenraad Haverkamp+" nrofvoyages="1"/>',
#  '<master name="Simon Vaartjes" nrofvoyages="5"/>',
#  '<master name="Klaas Voet" nrofvoyages="4"/>',
#  '<master name="Johan Gallo" nrofvoyages="1"/>',
#  '<master name="Matthijs van der Balk" nrofvoyages="1"/>',
#  '<master name="Christiaan Martens" nrofvoyages="2"/>',
#  '<master name="Luur Runken" nrofvoyages="5"/>',
#  '<master name="Karel Frederik Schaak" nrofvoyages="2"/>',
#  '<master name="Johan van Stralen" nrofvoyages="2"/>',
#  '<master name="August Willem Hass+" nrofvoyages="1"/>',
#  '<master name="Herman Driesman" nrofvoyages="3"/>',
#  '<master name="Wietse de Boer" nrofvoyages="3"/>',
#  '<master name="Hendrik Blok" nrofvoyages="1"/>',
#  '<master name="Theodorus Toussaint" nrofvoyages="1"/>',
#  '<master name="David Hartig" nrofvoyages="1"/>',
#  '<master name="Jan Andries Rugee+" nrofvoyages="1"/>',
#  '<master name="Johan Pleen" nrofvoyages="3"/>',
#  '<master name="Hendrik Holder" nrofvoyages="3"/>',
#  '<master name="Nikolaas Klopper" nrofvoyages="3"/>',
#  '<master name="Willem Jakob Kudde" nrofvoyages="1"/>',
#  '<master name="Jan Bringman" nrofvoyages="2"/>',
#  '<master name="Nils Lundstrom" nrofvoyages="2"/>',
#  '<master name="Jurriaan Pietersen" nrofvoyages="3"/>',
#  '<master name="Jakob Swetman" nrofvoyages="2"/>',
#  '<master name="Evert Wittenberg" nrofvoyages="4"/>',
#  '<master name="Harmen Ruurdsz." nrofvoyages="1"/>',
#  '<master name="Kornelis Reindertsz. Tromp" nrofvoyages="2"/>',
#  '<master name="Pieter Couvret" nrofvoyages="3"/>',
#  '<master name="Matthijs Laurens Koster" nrofvoyages="3"/>',
#  '<master name="Pieter Hol" nrofvoyages="2"/>',
#  '<master name="Dirk Dirksz. Varkevisser" nrofvoyages="3"/>',
#  '<master name="Dirk Sem" nrofvoyages="2"/>',
#  '<master name="Michiel Jurgens" nrofvoyages="2"/>',
#  '<master name="Johan Hendrik Gevels" nrofvoyages="2"/>',
#  '<master name="Lodewijk Elgenhuizen" nrofvoyages="3"/>',
#  '<master name="Kornelis de Vries" nrofvoyages="2"/>',
#  '<master name="Jan Gerrit Scholten" nrofvoyages="2"/>',
#  '<master name="Simon Krijgsman" nrofvoyages="2"/>',
#  '<master name="Hendrik Joosten" nrofvoyages="2"/>',
#  '<master name="Johan de Wolf" nrofvoyages="2"/>',
#  '<master name="Karel Volkman" nrofvoyages="2"/>',
#  '<master name="Eldert Evertsz." nrofvoyages="2"/>',
#  '<master name="Laurens Jansen" nrofvoyages="3"/>',
#  '<master name="Willem van Groningen" nrofvoyages="3"/>',
#  '<master name="DORDRECHT) Jan Dale" nrofvoyages="1"/>',
#  '<master name="Jan Roelofsz. de Groot" nrofvoyages="3"/>',
#  '<master name="Michiel Poest" nrofvoyages="2"/>',
#  '<master name="Klaas Zwart" nrofvoyages="3"/>',
#  '<master name="(HOLLAND) Simon Jakob Forster" nrofvoyages="2"/>',
#  '<master name="Jochem Hendrik Milfaart" nrofvoyages="2"/>',
#  '<master name="Abraham Tim" nrofvoyages="5"/>',
#  '<master name="Willem Frederiks" nrofvoyages="1"/>',
#  '<master name="Pleun van der Giessen" nrofvoyages="2"/>',
#  '<master name="Pieter Kornelissen" nrofvoyages="1"/>',
#  '<master name="Not used" nrofvoyages="3"/>',
#  '<master name="Herman Kikkert" nrofvoyages="1"/>',
#  '<master name="Gerrit Jan van de Kerkhof" nrofvoyages="1"/>',
#  '<master name="Arie Pijlhart" nrofvoyages="1"/>',
#  '<master name="Pierre Frederik Riebe" nrofvoyages="3"/>',
#  '<master name="Gerrit Gerritsen" nrofvoyages="1"/>',
#  '<master name="Pieter Bentse" nrofvoyages="1"/>',
#  '<master name="Jakob Smit" nrofvoyages="2"/>',
#  '<master name="Francois Aemonet" nrofvoyages="1"/>',
#  '<master name="Lodewijk Kappelhof" nrofvoyages="2"/>',
#  '<master name="Kornelis Lorein" nrofvoyages="1"/>',
#  '<master name="Pieter Moddetman" nrofvoyages="1"/>',
#  '<master name="Massaut" nrofvoyages="1"/>',
#  '<master name="Jacques Lourde Martignac" nrofvoyages="1"/>',
#  '<master name="Mareches" nrofvoyages="1"/>',
#  '<master name="Pieter Andriessen" nrofvoyages="1"/>',
#  '<master name="Jan Isaac" nrofvoyages="1"/>',
#  '<master name="(BONNE) Andries Lundgren" nrofvoyages="1"/>',
#  '<master name="Arie van der Giessen" nrofvoyages="2"/>',
#  '<master name="Pieter Arwidson" nrofvoyages="1"/>',
#  '<master name="Jan Jurgen Christiaan Meyer" nrofvoyages="1"/>',
#  '<master name="Saulnier" nrofvoyages="1"/>',
#  '<master name="Isaak Thierens" nrofvoyages="2"/>',
#  '<master name="Franc Odievre" nrofvoyages="1"/>',
#  '<master name="Johan George Kinborg" nrofvoyages="1"/>',
#  '<master name="Le Vasnier" nrofvoyages="1"/>',
#  '<master name="Pieter Menard" nrofvoyages="1"/>',
#  '<master name="Pieter Kolom" nrofvoyages="1"/>',
#  '<master name="Joseph le Naux" nrofvoyages="1"/>',
#  '<master name="Karel Alm" nrofvoyages="1"/>',
#  '<master name="Klaas Breitholz" nrofvoyages="1"/>',
#  '<master name="Gottfried Dahl" nrofvoyages="1"/>',
#  '<master name="La Fayde de Branchere" nrofvoyages="1"/>',
#  '<master name="Honore Roux" nrofvoyages="1"/>',
#  '<master name="Jan Tromp" nrofvoyages="5"/>',
#  '<master name="Sijbrand Sax" nrofvoyages="1"/>',
#  '<master name="Oyer" nrofvoyages="1"/>',
#  '<master name="Isaak de Vries" nrofvoyages="8"/>',
#  '<master name="Philippo Nery da Silva" nrofvoyages="1"/>',
#  '<master name="Jan Nieuwenhuis" nrofvoyages="1"/>',
#  '<master name="Jakob van den Berg" nrofvoyages="5"/>',
#  '<master name="Jan van der Sloot" nrofvoyages="1"/>',
#  '<master name="Justus van Gennep" nrofvoyages="2"/>',
#  '<master name="Jan Willem Mekau" nrofvoyages="1"/>',
#  '<master name="Gerrit Opdal" nrofvoyages="2"/>',
#  '<master name="Jan Willem Nieder" nrofvoyages="2"/>',
#  '<master name="Evert Wesseling" nrofvoyages="2"/>',
#  '<master name="N.Ketel Jakobsz." nrofvoyages="1"/>',
#  '<master name="Johan de Korte" nrofvoyages="2"/>',
#  '<master name="Jakob de Lange" nrofvoyages="4"/>',
#  '<master name="Vegter van de Koog" nrofvoyages="1"/>',
#  '<master name="Kornelis Damme" nrofvoyages="3"/>',
#  '<master name="Joris van Kleef" nrofvoyages="6"/>',
#  '<master name="Christiaan Bakker" nrofvoyages="4"/>',
#  '<master name="Pieter Elsvliet" nrofvoyages="2"/>',
#  '<master name="Jurriaan Zeeman" nrofvoyages="4"/>',
#  '<master name="Salomon Reynders" nrofvoyages="2"/>',
#  '<master name="Arie de Ruyter" nrofvoyages="1"/>',
#  '<master name="Pieter Kaayman" nrofvoyages="3"/>',
#  '<master name="Koenraad van der Poel" nrofvoyages="4"/>',
#  '<master name="Kornelis van de Woestijne" nrofvoyages="2"/>',
#  '<master name="Huibrecht op den Dijk" nrofvoyages="6"/>',
#  '<master name="Olof Kuit +" nrofvoyages="1"/>',
#  '<master name="Samuel Hoppestijn van Leeuwen" nrofvoyages="4"/>',
#  '<master name="Dirk de Vet" nrofvoyages="12"/>',
#  '<master name="Pieter Alkmaar" nrofvoyages="3"/>',
#  '<master name="Willem Meyer" nrofvoyages="2"/>',
#  '<master name="Willem Cagie" nrofvoyages="3"/>',
#  '<master name="Jan Licent" nrofvoyages="4"/>',
#  '<master name="Willem van der Velden" nrofvoyages="3"/>',
#  '<master name="Anthonie Guldeman" nrofvoyages="4"/>',
#  '<master name="Pieter Bruis" nrofvoyages="7"/>',
#  '<master name="Dirk Pomp" nrofvoyages="1"/>',
#  '<master name="Jan Boelhouwer" nrofvoyages="3"/>',
#  '<master name="Elias Moeninx" nrofvoyages="4"/>',
#  '<master name="Pieter Geel" nrofvoyages="1"/>',
#  '<master name="Hans Nomsen" nrofvoyages="2"/>',
#  '<master name="Wouter Bos" nrofvoyages="3"/>',
#  '<master name="Pieter van der Sprenkel" nrofvoyages="2"/>',
#  '<master name="Jan Kolom" nrofvoyages="2"/>',
#  '<master name="Kornelis van Marle" nrofvoyages="1"/>',
#  '<master name="Lukas Krootjes" nrofvoyages="1"/>',
#  '<master name="Jan van Engelen" nrofvoyages="5"/>',
#  '<master name="Marinus Dringer" nrofvoyages="4"/>',
#  '<master name="Dirk Elsberg" nrofvoyages="2"/>',
#  '<master name="Gerrit Pik" nrofvoyages="7"/>',
#  '<master name="Klaas Meelhoop" nrofvoyages="4"/>',
#  '<master name="Gerrit van der Jolle" nrofvoyages="1"/>',
#  '<master name="Abraham Everhard" nrofvoyages="3"/>',
#  '<master name="Hendrik Orsel" nrofvoyages="4"/>',
#  '<master name="Leonard de Rijke" nrofvoyages="6"/>',
#  '<master name="Pieter Scherf" nrofvoyages="10"/>',
#  '<master name="Marten Burgers" nrofvoyages="3"/>',
#  '<master name="Simon Mulder" nrofvoyages="1"/>',
#  '<master name="Joris Davidson" nrofvoyages="8"/>',
#  '<master name="Herman de Vrij" nrofvoyages="7"/>',
#  '<master name="Kornelis de Ruiter" nrofvoyages="7"/>',
#  '<master name="Arie van der Stolk" nrofvoyages="2"/>',
#  '<master name="Jakob Bernards" nrofvoyages="4"/>',
#  '<master name="Lambert Zwaan" nrofvoyages="7"/>',
#  '<master name="Adriaan van Rensen" nrofvoyages="3"/>',
#  '<master name="Daniel van Staden" nrofvoyages="6"/>',
#  '<master name="Pieter Kronenburg" nrofvoyages="5"/>',
#  '<master name="Lukas Rozeboom" nrofvoyages="4"/>',
#  '<master name="Jan de Haan" nrofvoyages="8"/>',
#  '<master name="Adriaan Krielaard" nrofvoyages="2"/>',
#  '<master name="Kornelis van der Hoeve" nrofvoyages="4"/>',
#  '<master name="Herman Blom" nrofvoyages="1"/>',
#  '<master name="Mauritius van der Star" nrofvoyages="2"/>',
#  '<master name="Gerrit Klinkhamer" nrofvoyages="4"/>',
#  '<master name="Pieter van Hoom" nrofvoyages="1"/>',
#  '<master name="Jan Bot" nrofvoyages="3"/>',
#  '<master name="Jan Pereboom" nrofvoyages="8"/>',
#  '<master name="Barend Lont" nrofvoyages="1"/>',
#  '<master name="Viktor van der Kaag" nrofvoyages="3"/>',
#  '<master name="Gijsbert Hageman" nrofvoyages="2"/>',
#  '<master name="Hendrik Schoon" nrofvoyages="8"/>',
#  '<master name="Jan Krielaard" nrofvoyages="6"/>',
#  '<master name="Samuel Hoppestijn" nrofvoyages="3"/>',
#  '<master name="Frederik Hendrik Meerme" nrofvoyages="1"/>',
#  '<master name="Pieter Kaas" nrofvoyages="4"/>',
#  '<master name="Pieter Lup" nrofvoyages="2"/>',
#  '<master name="Nikolaas du Moulin" nrofvoyages="3"/>',
#  '<master name="Diederik van den Zandheuvel" nrofvoyages="1"/>',
#  '<master name="Gerrit Bijleveld" nrofvoyages="3"/>',
#  '<master name="Jan Mijndertsz." nrofvoyages="3"/>',
#  '<master name="1. Muisenhoofd" nrofvoyages="1"/>',
#  '<master name="Willem Braakman" nrofvoyages="1"/>',
#  '<master name="(NIEUWE) Lukas Semeyns" nrofvoyages="1"/>',
#  '<master name="Arie Brouwer" nrofvoyages="7"/>',
#  '<master name="Hendrik Perfekt" nrofvoyages="4"/>',
#  '<master name="Kornelis Fret" nrofvoyages="11"/>',
#  '<master name="Jurriaan Lijssen" nrofvoyages="1"/>',
#  '<master name="Jan van Malen" nrofvoyages="2"/>',
#  '<master name="Jan de Roeper" nrofvoyages="3"/>',
#  '<master name="Jakob Gosen Hoogstad" nrofvoyages="5"/>',
#  '<master name="Klaas Melop" nrofvoyages="1"/>',
#  '<master name="Willem Haysen" nrofvoyages="3"/>',
#  '<master name="Gerrit Kuit" nrofvoyages="4"/>',
#  '<master name="Wouter Bois" nrofvoyages="1"/>',
#  '<master name="Adriaan de Wit" nrofvoyages="1"/>',
#  '<master name="Kornelis Roobol" nrofvoyages="3"/>',
#  '<master name="Hendrik Jansz.van Beek" nrofvoyages="1"/>',
#  '<master name="Frans Gartelman" nrofvoyages="2"/>',
#  '<master name="Jan Almees" nrofvoyages="8"/>',
#  '<master name="Adriaan van Leeuwen" nrofvoyages="5"/>',
#  '<master name="Abraham van der Hart" nrofvoyages="3"/>',
#  '<master name="Simon Muller" nrofvoyages="3"/>',
#  '<master name="Jakob van der Blok +" nrofvoyages="1"/>',
#  '<master name="Evert de Bruin" nrofvoyages="7"/>',
#  '<master name="Abraham van Rijnoy" nrofvoyages="1"/>',
#  '<master name="Kornelis den Breen" nrofvoyages="2"/>',
#  '<master name="Herman Brand +" nrofvoyages="1"/>',
#  '<master name="Gerrit Fiers" nrofvoyages="9"/>',
#  '<master name="Dirk Mulder" nrofvoyages="2"/>',
#  '<master name="Christiaan Damme" nrofvoyages="2"/>',
#  '<master name="Jan Meulman" nrofvoyages="3"/>',
#  '<master name="Jan van den Elske" nrofvoyages="3"/>',
#  '<master name="Pieter Obry" nrofvoyages="3"/>',
#  '<master name="Kornelis Jonker+" nrofvoyages="1"/>',
#  '<master name="Pieter Verley" nrofvoyages="10"/>',
#  '<master name="Lukas Hardenbroek" nrofvoyages="3"/>',
#  '<master name="Gillis Oudemans" nrofvoyages="3"/>',
#  '<master name="Boudewijn de Graaf" nrofvoyages="5"/>',
#  '<master name="Levinus de Heere" nrofvoyages="4"/>',
#  '<master name="Jakob Landsheer" nrofvoyages="5"/>',
#  '<master name="Hendrik van den Berg" nrofvoyages="7"/>',
#  '<master name="Pieter van de Roete" nrofvoyages="5"/>',
#  '<master name="Adriaan de Raad+" nrofvoyages="1"/>',
#  '<master name="Willem van Ginkel" nrofvoyages="4"/>',
#  '<master name="Michiel van Markel" nrofvoyages="4"/>',
#  '<master name="Kornelis Oterlijk" nrofvoyages="5"/>',
#  '<master name="Joachim Galouw" nrofvoyages="1"/>',
#  '<master name="Isaak Brandenburg" nrofvoyages="6"/>',
#  '<master name="Dirk Dol" nrofvoyages="2"/>',
#  '<master name="Huibert Haringvanger" nrofvoyages="1"/>',
#  '<master name="Klaas Molenaar" nrofvoyages="2"/>',
#  '<master name="Dirk Goudberg" nrofvoyages="2"/>',
#  '<master name="Hendrik Oterlijk" nrofvoyages="3"/>',
#  '<master name="Huig Goedhart" nrofvoyages="7"/>',
#  '<master name="Kornelis van der Kolster" nrofvoyages="7"/>',
#  '<master name="Marinus Commerse" nrofvoyages="4"/>',
#  '<master name="Pieter Timmerman" nrofvoyages="6"/>',
#  '<master name="Kornelis Brouw" nrofvoyages="2"/>',
#  '<master name="Adriaan van der Graaf" nrofvoyages="2"/>',
#  '<master name="Jan Reebok" nrofvoyages="6"/>',
#  '<master name="Jan van der Quade" nrofvoyages="6"/>',
#  '<master name="Pieter Tinnekens" nrofvoyages="3"/>',
#  '<master name="Hendrik Beene" nrofvoyages="3"/>',
#  '<master name="Michiel de Reus" nrofvoyages="8"/>',
#  '<master name="Jan de Marre" nrofvoyages="4"/>',
#  '<master name="Hendrik Smit" nrofvoyages="7"/>',
#  '<master name="Gerrit van Wezel" nrofvoyages="5"/>',
#  '<master name="Albert Visser" nrofvoyages="6"/>',
#  '<master name="Jan van Est" nrofvoyages="5"/>',
#  '<master name="Barend van der Zalm" nrofvoyages="3"/>',
#  '<master name="Jakob van der Swet" nrofvoyages="6"/>',
#  '<master name="Jakob van der Beek" nrofvoyages="2"/>',
#  '<master name="Jurriaan Popta" nrofvoyages="5"/>',
#  '<master name="Isaak Hage" nrofvoyages="7"/>',
#  '<master name="Daniel Overbeek" nrofvoyages="6"/>',
#  '<master name="Jan Hokkeling" nrofvoyages="3"/>',
#  '<master name="Kornelis Klaasz." nrofvoyages="5"/>',
#  '<master name="Adriaan de Raad" nrofvoyages="3"/>',
#  '<master name="Herman Brand" nrofvoyages="3"/>',
#  '<master name="Hendrik Klooster" nrofvoyages="5"/>',
#  '<master name="Adam van Ingen" nrofvoyages="4"/>',
#  '<master name="Adriaan van den Berg" nrofvoyages="5"/>',
#  '<master name="Isaak Rombouts" nrofvoyages="6"/>',
#  '<master name="Frans van der Hoop" nrofvoyages="2"/>',
#  '<master name="Adriaan Krijnsen" nrofvoyages="2"/>',
#  '<master name="Anthonie Klink" nrofvoyages="6"/>',
#  '<master name="Mijndert Schut" nrofvoyages="5"/>',
#  '<master name="Adriaan van Dorp" nrofvoyages="5"/>',
#  '<master name="Paulus Erasmus" nrofvoyages="5"/>',
#  '<master name="Pieter Groothuis" nrofvoyages="2"/>',
#  '<master name="Lodewijk Verburg" nrofvoyages="3"/>',
#  '<master name="Nikolaas Anderson" nrofvoyages="3"/>',
#  '<master name="Kornelis Lans" nrofvoyages="3"/>',
#  '<master name="Jan Schul" nrofvoyages="5"/>',
#  '<master name="Pieter van Genechten" nrofvoyages="2"/>',
#  '<master name="Hendrik Schadee" nrofvoyages="2"/>',
#  '<master name="Jan Molentijn" nrofvoyages="3"/>',
#  '<master name="Willem de Smit" nrofvoyages="3"/>',
#  '<master name="Kornelis Rees" nrofvoyages="4"/>',
#  '<master name="Pieter Thomas van Dijk" nrofvoyages="1"/>',
#  '<master name="Klaas Zeeridder" nrofvoyages="7"/>',
#  '<master name="Willem Huigen" nrofvoyages="2"/>',
#  '<master name="Jakob Jongerheld" nrofvoyages="4"/>',
#  '<master name="Gelijn de Haas" nrofvoyages="5"/>',
#  '<master name="Jan Verschouw" nrofvoyages="6"/>',
#  '<master name="Willem Verbeek" nrofvoyages="3"/>',
#  '<master name="Hendrik van der Grippe" nrofvoyages="9"/>',
#  '<master name="Gideon Kuiper" nrofvoyages="7"/>',
#  '<master name="Klaas Goethoen" nrofvoyages="1"/>',
#  '<master name="Paulus Tideman" nrofvoyages="1"/>',
#  '<master name="Jonas Mierman" nrofvoyages="7"/>',
#  '<master name="Jan de Graaf" nrofvoyages="6"/>',
#  '<master name="Hendrik Vegt" nrofvoyages="2"/>',
#  '<master name="Gerrit Stokke" nrofvoyages="6"/>',
#  '<master name="Pieter Knollendam" nrofvoyages="5"/>',
#  '<master name="Jakob Kooimans" nrofvoyages="8"/>',
#  '<master name="Dirk de Visser" nrofvoyages="3"/>',
#  '<master name="Pieter Tinnekes" nrofvoyages="1"/>',
#  '<master name="Jan van der Heiden" nrofvoyages="8"/>',
#  '<master name="Matthijs Zwaan" nrofvoyages="3"/>',
#  '<master name="Abraham van den Busse" nrofvoyages="2"/>',
#  '<master name="Hendrik Thieling" nrofvoyages="6"/>',
#  '<master name="IJpe Engelsman" nrofvoyages="4"/>',
#  '<master name="Thomas Fletcher" nrofvoyages="5"/>',
#  '<master name="Jan van den Broek" nrofvoyages="4"/>',
#  '<master name="Klaas Jonker" nrofvoyages="3"/>',
#  '<master name="Joost Nose" nrofvoyages="3"/>',
#  '<master name="Jan Diephout" nrofvoyages="5"/>',
#  '<master name="Joris Vermouwe" nrofvoyages="7"/>',
#  '<master name="Bartholomeus Teerling" nrofvoyages="2"/>',
#  '<master name="Jan de Vos" nrofvoyages="4"/>',
#  '<master name="Jakob Thoorn" nrofvoyages="3"/>',
#  '<master name="Balthus van Santen" nrofvoyages="3"/>',
#  '<master name="Jan Moerman" nrofvoyages="7"/>',
#  '<master name="Jakob van der Poel" nrofvoyages="11"/>',
#  '<master name="Adriaan Hijpe" nrofvoyages="5"/>',
#  '<master name="Hendrik Jurriaansz. van Beek" nrofvoyages="1"/>',
#  '<master name="Jakob Visser" nrofvoyages="7"/>',
#  '<master name="Willem de Leus" nrofvoyages="10"/>',
#  '<master name="Matthijs Burger" nrofvoyages="6"/>',
#  '<master name="Pieter van den Berg" nrofvoyages="4"/>',
#  '<master name="Jochem Thijssen" nrofvoyages="2"/>',
#  '<master name="Tijmen Mol" nrofvoyages="5"/>',
#  '<master name="David Kleeman" nrofvoyages="2"/>',
#  '<master name="Isaak de Haan" nrofvoyages="1"/>',
#  '<master name="Bastiaan Schul" nrofvoyages="6"/>',
#  '<master name="Hendrik Zilde" nrofvoyages="1"/>',
#  '<master name="Willem Staalman" nrofvoyages="2"/>',
#  '<master name="Marten Hartin" nrofvoyages="1"/>',
#  '<master name="Jan Schaap" nrofvoyages="2"/>',
#  '<master name="Kornelis Haringkarspel" nrofvoyages="3"/>',
#  '<master name="Willem de Keizer" nrofvoyages="3"/>',
#  '<master name="Gerbrand Mamus" nrofvoyages="11"/>',
#  '<master name="Matthijs Pingsternakel" nrofvoyages="3"/>',
#  '<master name="Jan Boot" nrofvoyages="2"/>',
#  '<master name="Jan Bloemendaal" nrofvoyages="5"/>',
#  '<master name="Anthonie Biermans" nrofvoyages="3"/>',
#  '<master name="Pieter Bellaart" nrofvoyages="3"/>',
#  '<master name="Abraham Bustijn" nrofvoyages="4"/>',
#  '<master name="Nikolaas van Langeveld" nrofvoyages="2"/>',
#  '<master name="Pieter van Pavie" nrofvoyages="2"/>',
#  '<master name="Theunis Brouisze" nrofvoyages="2"/>',
#  '<master name="Andries Pijl" nrofvoyages="9"/>',
#  '<master name="Christiaan Daniels" nrofvoyages="2"/>',
#  '<master name="Jakob Meindertsz. Blok" nrofvoyages="1"/>',
#  '<master name="Klaas van Eik" nrofvoyages="6"/>',
#  '<master name="Arie Jansz. Verduin" nrofvoyages="6"/>',
#  '<master name="Joost Roset" nrofvoyages="2"/>',
#  '<master name="Jan Hijpe" nrofvoyages="1"/>',
#  '<master name="Jan Rusteplukker" nrofvoyages="4"/>',
#  '<master name="Wouter Brand" nrofvoyages="2"/>',
#  '<master name="Laurens IJsenhart" nrofvoyages="2"/>',
#  '<master name="Jakob Breed" nrofvoyages="4"/>',
#  '<master name="Karel de Laver" nrofvoyages="1"/>',
#  '<master name="Hendrik Lont" nrofvoyages="7"/>',
#  '<master name="Jan van de Vijver" nrofvoyages="3"/>',
#  '<master name="Pieter van Dalen" nrofvoyages="6"/>',
#  '<master name="Jakob Onkruid" nrofvoyages="13"/>',
#  '<master name="Gerrit Pekstok" nrofvoyages="1"/>',
#  '<master name="Marten Harting" nrofvoyages="6"/>',
#  '<master name="Wouter van Dijk" nrofvoyages="7"/>',
#  '<master name="Jan Laurens de Hoge" nrofvoyages="4"/>',
#  '<master name="Jan Credo" nrofvoyages="4"/>',
#  '<master name="Arend Dirksz. Bent" nrofvoyages="4"/>',
#  '<master name="Elias Wargaren" nrofvoyages="5"/>',
#  '<master name="Dirk Renvoort" nrofvoyages="4"/>',
#  ...]

# %% [markdown]
# (b) Return the master element(s) of the master(s) with the most voyages. (There are 3 masters that did
# 16 voyages)

# %%
xquery = """
subsequence(let $doc := doc('Downloads/voc.xml')
for $voyage in $doc/VOC/voyage
let $master := $voyage/leftpage/master
where $master
group by $master
order by count($voyage) descending
return <master name='{$master}' nrofvoyages='{count($voyage)}'/>, 1, 3)
"""
run_xquery(xquery)
# Out:
# ['<master name="Kornelis Pietersen" nrofvoyages="16"/>',
#  '<master name="Jakob de Vries" nrofvoyages="16"/>',
#  '<master name="Pieter Visser" nrofvoyages="16"/>']
